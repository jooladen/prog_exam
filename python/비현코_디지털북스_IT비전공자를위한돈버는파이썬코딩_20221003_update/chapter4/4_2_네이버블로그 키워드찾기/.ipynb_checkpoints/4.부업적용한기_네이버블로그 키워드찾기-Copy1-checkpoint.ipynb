# %% [markdown]
# # 상황설정
#
#
# 1. 원하는 키워드를 선정한다.
# 2. 네이버 API 아이디/비번 발행
# 3. 네이버 검색 API를 해당키워드의 최근 100개의 발행개수를 확인한다.
# 4. 해당 키워드의 포스팅일자와 총 발행량을 체크한다.
# 5. 오늘 글을 올렸을 때의 경쟁률을 알아본다.
# 6. 원코드로 만든다.

# %% [markdown]
# 1. 원하는 키워드를 선정한다.

# %%
keyword = str(input("원하는 키워드를 선정하세요 : "))
# Out:
# 원하는 키워드를 선정하세요 : 네이버API 신청방법

# %%
#write your code (100문이 일여불타)

# %% [markdown]
# 2. 네이버 API 아이디/비번 발행

# %%
# 네이버 검색 , 아이디/비번 발행
client_id = "ubkbaBd5PuSnpM4japzP"

import getpass
client_secret = getpass.getpass("클라이언트 시크릿을 입력하세요 : ")
# Out:
# 클라이언트 시크릿을 입력하세요 : ········

# %%
#write your code (100문이 일여불타)

# %% [markdown]
# 3. 네이버 검색 API를 해당키워드의 최근 1000개의 발행개수를 확인한다.

# %%
# 네이버 검색 API를 해당키워드의 최근 100개의 발행개수를 확인한다.
import json
import os
import sys
import urllib.request
# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"
encText = urllib.parse.quote(keyword)
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과

display = 100
sort = 'date'

url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=" + str(display) + "&sort=" + str(sort)

# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()

    #나오는 결과를 json 으로 변환해서 가져오는작업
    response_dict = json.loads(response_body.decode('utf-8'))
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 22 Jan 2021 07:31:29 +0900",
# "total": 1625,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "조회수 순위 2021.01.11. ~ 2021.01.17. 주간",
# "link": "https:\/\/blog.naver.com\/medosam?Redirect=Log&logNo=222214670302",
# "description": "(화)233빛으로 결정체 분자를 튀겨 마이크로로봇을 추진시키는 <b>방법</b>32019.11.28. (목)172SKT... (일)233<b>네이버</b>클라우드·KT가 SaaS에 공들이는 까닭32021.01.10. (일)233조회수 순위 2021.01.09.... ",
# "bloggername": "4차산업혁명",
# "bloggerlink": "https://blog.naver.com/medosam",
# "postdate": "20210121"
#
# },
# {
# "title": "내 블로그 생성일을 알아보자 클릭 3번이면 끝feat 애드포스트",
# "link": "https:\/\/blog.naver.com\/viottis82110?Redirect=Log&logNo=222213828253",
# "description": "<b>방법</b>입니다. 3) 아래로 내리면 제일 하단에서 '블로그 개설일'을 확인할 수 있습니다. 일상대화 <b>API</b>... 명칭으로 <b>네이버</b>에 <b>신청</b>할수 있어요 암튼 참고하시고 혹시 비슷한 경험이 있으시다면 힘을 실어주세요^^ 내... ",
# "bloggername": "viottis82110님의블로그",
# "bloggerlink": "https://blog.naver.com/viottis82110",
# "postdate": "20210120"
#
# },
# {
# "title": "디스크랩 쿠팡 대량등록 플레이오토 활용 상품 등록",
# "link": "https:\/\/blog.naver.com\/swara_wear?Redirect=Log&logNo=222213704552",
# "description": "<b>네이버</b>에 상품이 등록되어 있으신 가요? 쿠팡에서 플레이오토와 협업하여 디스크랩으로 소싱한... [발급<b>방법</b> 보러가기] 버튼을 클릭하여 각각의 id 를 발급 받으시면 됩니다. 쉽게 <b>API</b> 로 상품 가져오기!... ",
# "bloggername": "디스크랩",
# "bloggerlink": "https://blog.naver.com/swara_wear",
# "postdate": "20210120"
#
# },
# {
# "title": "스마트스토어 이름 변경하기 (스토어명과 스토어주소 URL 변경)",
# "link": "https:\/\/blog.naver.com\/johnaver?Redirect=Log&logNo=222212764951",
# "description": "- 스토어명 변경을 해야 스토어 주소 URL 변경 <b>신청</b>이 가능함(직접은 안되고 고객센터로 요청 필요)... 이상과 같이 운영중인 <b>네이버</b> 스마트스토어 이름과 주소 URL을 변경하는 <b>방법</b>에 대해서... ",
# "bloggername": "부자아빠 조블랙의 황금책장",
# "bloggerlink": "https://blog.naver.com/johnaver",
# "postdate": "20210119"
#
# },
# {
# "title": "[Selenium] Window10에 셀레니움(셀레늄) 서버 사용하기",
# "link": "https://yoshikixdrum.tistory.com/222",
# "description": "그래서 <b>네이버</b> 개발자 센터에서 데이터랩 <b>API</b>를 <b>신청</b>했는데 알고 보니 해당 데이터는 <b>API</b>로 제공하고 있지 않았습니다. 그래서 다른 <b>방법</b>이자 원초적인 크롤링을 통해서 접근을 하기 위해서... ",
# "bloggername": "평범한 이야기들",
# "bloggerlink": "http://yoshikixdrum.tistory.com/",
# "postdate": "20210119"
#
# },
# {
# "title": "스마트스토어할 때 효과적인 <b>방법</b>이 있을까?-4",
# "link": "https:\/\/blog.naver.com\/tjrals34?Redirect=Log&logNo=222211228913",
# "description": "<b>네이버</b> 윈도에 입점하는 <b>방법</b>은 스마크스토어 판매자센터 하단에 잘 나와 있다. 05. 기획전 -기획전은... 럭키투데이는 아래와 같은 <b>신청</b> 조건과 진행요건, 필수 조건들이 있다. 1)럭키투데이는 스마트스토어... ",
# "bloggername": "오늘보다가치있는내일",
# "bloggerlink": "https://blog.naver.com/tjrals34",
# "postdate": "20210118"
#
# },
# {
# "title": "[신문스크랩] 스타트업 및 창업",
# "link": "https:\/\/blog.naver.com\/did3238?Redirect=Log&logNo=222211204150",
# "description": "지원사업을 <b>신청</b>하는 것부터 힘들어하고 있을 때 서울대 교수에게 멘토링을 받으며 사업계획서와... nidx=376173&amp;depth1=2&amp;depth2=1&amp;depth3=1 창업지원금 `그림의 떡`…&quot;절차 복잡해 중도 포기&quot; : <b>네이버</b> 뉴스 (naver.com)... ",
# "bloggername": "파워성장러_디혜의 삶",
# "bloggerlink": "https://blog.naver.com/did3238",
# "postdate": "20210118"
#
# },
# {
# "title": "01월17일 경제소식 (오후)",
# "link": "https:\/\/blog.naver.com\/ddk8942?Redirect=Log&logNo=222210395143",
# "description": "연납 <b>신청</b>을 받고 있다. 매년 6월과 12월에 정기적으로 부과되는 자동차세를 1월에 전액 선납하면 공제기간 세액을 할인해주는 제도로, 기한 내에 연납<b>신청</b>을 할 경우 연세액의 약 9.15%를 공제받을... ",
# "bloggername": "부자로 가는길",
# "bloggerlink": "https://blog.naver.com/ddk8942",
# "postdate": "20210117"
#
# },
# {
# "title": "스파르타 코딩클럽 개인 프로젝트",
# "link": "https:\/\/blog.naver.com\/fnek273?Redirect=Log&logNo=222209417619",
# "description": "저장 -<b>네이버</b> 지도 <b>API신청</b>후 서버를 완성 -HTML파일을 이용하여 태그를 만들어 지도에 마커를 띠움 3. 어려웠던점, 극복<b>방법</b> -처음 배웠던 내용들이 기억이 잘 안나서 이전 강의자료들을 다시 찾아보며... ",
# "bloggername": "fnek273님의블로그",
# "bloggerlink": "https://blog.naver.com/fnek273",
# "postdate": "20210116"
#
# },
# {
# "title": "2021.1.16, 최신 경제정책",
# "link": "https:\/\/blog.naver.com\/ds1mpt?Redirect=Log&logNo=222209283789",
# "description": "1527Page「고용부-<b>네이버</b>·카카오-인력공단·대한상의」 업무협약 체결고용노동부2021.01.... Open <b>API</b> 제공금융감독원2021.01.129Page「생물학적제제 기준 및 시험<b>방법</b>」 개정안... ",
# "bloggername": "인천경제전망대",
# "bloggerlink": "https://blog.naver.com/ds1mpt",
# "postdate": "20210116"
#
# },
# {
# "title": "쿠팡파트너스 첫수익 후 승인완료 이메일 받는 <b>방법</b>... ",
# "link": "https:\/\/blog.naver.com\/julies2s2?Redirect=Log&logNo=222209270409",
# "description": "* 추천코드 하시면 서로 커미션 3%에서 4%로 높게 받으실 수 있어요 AF0326770 * <b>네이버</b> 애드포스트... <b>API</b> 발급 이렇게 메일함에 가입 <b>신청</b> 최종 승인 이메일이 도착했습니다.~~ 첫 수익이 났는데도 아직 최종... ",
# "bloggername": "쥬리의 짠테크 이야기",
# "bloggerlink": "https://blog.naver.com/julies2s2",
# "postdate": "20210116"
#
# },
# {
# "title": "블로그 상위 노출 시키는 <b>방법</b>? 키워드검색, 혜자스러운... ",
# "link": "https:\/\/blog.naver.com\/mninam?Redirect=Log&logNo=222208852560",
# "description": "쿠팡 <b>API</b>(프로그램)+<b>네이버 API</b> 결합하여 매크로 프로그램을 만들어냄. 그래서 [D.I.A +] 등장 양질의 글도... ex) 카카오톡 이모티콘 정액제 관련 가격, 결제 금액, 가입<b>방법</b>, <b>신청방법</b>, 해지 <b>방법</b>을 궁금해할꺼야.... ",
# "bloggername": "부:(富)쓰리 : 부엉이 부동산 부자되기♥",
# "bloggerlink": "https://blog.naver.com/mninam",
# "postdate": "20210115"
#
# },
# {
# "title": "웹개발 : 입문부터 취업 준비 A to Z",
# "link": "https:\/\/blog.naver.com\/tjrdls0817?Redirect=Log&logNo=222208423381",
# "description": "학습 <b>방법</b>부터 취업 준비까지, 국비지원 훈련 기관 등 웹 개발 이외 IT 분야에 관심이 있는 분들이라면 아래 <b>네이버</b>폰으로 상담 <b>신청</b> 남겨주시길 바랍니다. 지금까지 웹 개발 입문부터 취업에 대한 내용을... ",
# "bloggername": "luckychae",
# "bloggerlink": "https://blog.naver.com/tjrdls0817",
# "postdate": "20210115"
#
# },
# {
# "title": "리뷰 - 비전공자를 위한 이해할 수 있는 IT 지식",
# "link": "https:\/\/blog.naver.com\/lsk9201?Redirect=Log&logNo=222207932379",
# "description": "코딩 : <b>네이버</b>, 다음은 모바일용 웹페이지를 따로 운영 / 중복 작업의 불편을 덜기 위하여 반응형... 위한 <b>방법</b> :<b>API</b> 문서 확인 - 이미지 주소(URL)를 서버에서 받아온다면 그 이미지는 서버에 있는... ",
# "bloggername": "Book by Book",
# "bloggerlink": "https://blog.naver.com/lsk9201",
# "postdate": "20210115"
#
# },
# {
# "title": "[독서] N잡하는 허대리의 월급독립스쿨",
# "link": "https:\/\/blog.naver.com\/iamyooon?Redirect=Log&logNo=222207753613",
# "description": "강의 <b>신청</b>날에는 <b>신청</b> 안내 문자 메세지를, 강의 하루전에는 내일 강의라는 것과 주의사항을, 당일에는 장소 약도와 오는 <b>방법</b>에 대한 메세지를 보내자. 강의 시간에는 이름표와 함께 간단한 간식을... ",
# "bloggername": "iamyooon님의블로그",
# "bloggerlink": "https://blog.naver.com/iamyooon",
# "postdate": "20210115"
#
# },
# {
# "title": "2021년 대폭인상된 자동차보험료, 조금이라도 적게 내는 <b>방법</b>",
# "link": "https:\/\/blog.naver.com\/bohumbetter?Redirect=Log&logNo=222205043278",
# "description": "누락된 검색어: 대폭 자동차 조금 이라도 2021년 지역가입자 건강보험료 계산 <b>방법</b> : <b>네이버</b>... com › public › blog › html 건보료 부담 더는 5가지 <b>방법</b> 2019.12.23. '임의가입' <b>신청</b>하면 퇴직 3년 간... ",
# "bloggername": "자동차보험료비교견적",
# "bloggerlink": "https://blog.naver.com/bohumbetter",
# "postdate": "20210112"
#
# },
# {
# "title": "2021년 ICT 미래 시장 최적화 협업 기술 개발 사업 신규 공고... ",
# "link": "https:\/\/blog.naver.com\/kotera?Redirect=Log&logNo=222203786317",
# "description": "따라 <b>신청</b>하여 주시기 바랍니다. 2021년 1월 6일 과학기술정보통신부 장관 □ 사업목적... 지원<b>방법</b> : 先 시장수요 예측 및 검증 후 기술개발 지원 시장 수요예측 및 검증 지원 프로세스는 `21.4~6월까지 약... ",
# "bloggername": "정책자금에 관한 모든 것",
# "bloggerlink": "https://blog.naver.com/kotera",
# "postdate": "20210111"
#
# },
# {
# "title": "2021년 자동차보험료 인상에 대처하는 우리의 자세",
# "link": "https:\/\/blog.naver.com\/bohumbetter?Redirect=Log&logNo=222203138558",
# "description": "4월 보험료인상에 대비하는 현명한 <b>방법</b> 추천 : <b>네이버</b> 블로그blog.naver.com › PostView 2020. 2. 26.... 1년 만에 당기순이익의 4분의 1이 증발했다. ... 여타 손보사들도 요율 검증 <b>신청</b>을 검토하는 등 자  ",
# "bloggername": "자동차보험료비교견적",
# "bloggerlink": "https://blog.naver.com/bohumbetter",
# "postdate": "20210110"
#
# },
# {
# "title": "[2021년 1월 공모주] 핑거 청약일정, 공모가 및 주가전망은?",
# "link": "https:\/\/blog.naver.com\/zalga12?Redirect=Log&logNo=222202605717",
# "description": "청약<b>방법</b>에 대해서 잘 모르시는분도 계신거 같아서 간단히 말씀드리겠습니다. 1. 핑거 주관사인 증권사계좌개설 2. 해당 계좌에 예수금 입금 3. 핑거 공모청약일에 청약을 <b>신청</b>(전화, 인터넷/모바일등) 4.... ",
# "bloggername": "철티비 재테크 블로그",
# "bloggerlink": "https://blog.naver.com/zalga12",
# "postdate": "20210110"
#
# },
# {
# "title": "레노버 아이디어패드 S340-14<b>API</b> Picasso R5",
# "link": "https:\/\/blog.naver.com\/vavisuit88?Redirect=Log&logNo=222202316149",
# "description": "기본제품으로 <b>신청</b>을 했다. 340S-14<b>API</b> 는 유선랜포트를 갖추지 않은 제품이므로 기가랜카드와 젠더, 업그레드이용 4G 램을 추가로 구입을 했다. 구입처 : <b>네이버</b> 컴퓨존 구입가 : 41,620원 램... ",
# "bloggername": "雜動散異",
# "bloggerlink": "https://blog.naver.com/vavisuit88",
# "postdate": "20210109"
#
# },
# {
# "title": "12월 10일 모야(MoYa) 데일리 뉴스 모음 (인공지능,핀테크... ",
# "link": "https:\/\/blog.naver.com\/fyonj_am69724?Redirect=Log&logNo=222201356074",
# "description": "<b>네이버</b>클라우드-건양대, 의료 AI 인재 육성 위해 맞손2020-12-09 22:36:00 이진영 기자 또 기술 지원과 교직원 및 재학생을 대상으로 한 클라우드 컴퓨팅 서비스 교육을 지원할 예정이다. <b>네이버</b>클라... ",
# "bloggername": "fyonj_am69724님의블로그",
# "bloggerlink": "https://blog.naver.com/fyonj_am69724",
# "postdate": "20210109"
#
# },
# {
# "title": "해피톡 2021년 1월 1주차 업데이트 안내 – <b>네이버</b>... ",
# "link": "https:\/\/blog.naver.com\/happytalkio?Redirect=Log&logNo=222201022071",
# "description": "연동 <b>방법</b>을 개선하였습니다. 기존에는 <b>API</b> 정보를 직접 조회하여 대행사 선택 및 <b>API</b> ID를 입력하는 절차를 거치도록 하였으나, 이번 업데이트를 통해 연동 가능한 <b>네이버</b> 톡톡 프로필 선택 후 저장 시 바로... ",
# "bloggername": "해피톡, 고객을 잘 아는 기업들의 선택",
# "bloggerlink": "https://blog.naver.com/happytalkio",
# "postdate": "20210108"
#
# },
# {
# "title": "쿠팡 파트너스 <b>API</b> 및 최종 승인 안내",
# "link": "https://kjcc2.tistory.com/2455",
# "description": "최종 승인이 떨어지면 파트너스 <b>API</b>를 활성화시킬 수 있습니다. 쿠팡 파트너스 <b>API</b>도 다른 <b>API</b>들과... 29 코로나바이러스(COVID-19) 긴급재난지원금 <b>신청방법</b>(feat, 우리카드) (0) 2020.05.12 2020년도 <b>네이버</b> 웹툰... ",
# "bloggername": "http://kjcc2.tistory.com/",
# "bloggerlink": "http://kjcc2.tistory.com/",
# "postdate": "20210108"
#
# },
# {
# "title": "r프로그래밍강의 여기로!",
# "link": "https:\/\/blog.naver.com\/itsdongs?Redirect=Log&logNo=222199389382",
# "description": "느껴지신다면 <b>네이버</b> 아이디로도 간편구매가 가능하다고 하니 참고하신다면 좋을 것 같아요! 우선... 선택하는 <b>방법</b>들 중 하나가 맛보기 강의를 보는 것이라고 생각해요 맛보기 강의를 들어보고 나랑 맞으면 그... ",
# "bloggername": "아이티동스쿨 공식블로그",
# "bloggerlink": "https://blog.naver.com/itsdongs",
# "postdate": "20210107"
#
# },
# {
# "title": "브랜드 개체인식+Excel + Lists + Maps <b>API</b> + Power Apps",
# "link": "https:\/\/blog.naver.com\/sesme100?Redirect=Log&logNo=222199130908",
# "description": "Bing Maps <b>API</b> Key <b>신청</b>하기 # Microsoft 365를 구독해야합니다. 무료계정 1개월 체험을 위하여... 하기의 Docx 파일을 다운받으셔서 Microsoft 365 체험판을 받는 <b>방법</b>을 확인해보세요! 첨부파일... ",
# "bloggername": "A Daily Dose of Power Apps",
# "bloggerlink": "https://blog.naver.com/sesme100",
# "postdate": "20210107"
#
# },
# {
# "title": "비트코인 관련 사이트모음",
# "link": "https:\/\/blog.naver.com\/mesinzer?Redirect=Log&logNo=222198398682",
# "description": "- 모바일 결제, 사용<b>방법</b>, 용어, 커뮤니티, 이벤트, 콘퍼런스 안내. 빗썸 https://www.bithumb.com... com/upretty - 비트코인, 채굴, 라이트코인, 코빗, 시세, 거래 정보 제공, <b>네이버</b> 카페.... ",
# "bloggername": "보물찾기~처럼, 신나는 하루!",
# "bloggerlink": "https://blog.naver.com/mesinzer",
# "postdate": "20210106"
#
# },
# {
# "title": "홈페이지 제작업체",
# "link": "https:\/\/blog.naver.com\/mesinzer?Redirect=Log&logNo=222198312822",
# "description": "홈페이지제작 Biz http://www.xn--hu5b4brvf8c73w61d.biz - 맞춤형, 월정액 홈페이지 제작업체, 웹에이전시, 상담<b>신청</b> 안내. - 홈페이지제작 dm7 http://www.dm7.co.kr - 홈페이지 제작업체, 유지보수, 웹디자인... ",
# "bloggername": "보물찾기~처럼, 신나는 하루!",
# "bloggerlink": "https://blog.naver.com/mesinzer",
# "postdate": "20210106"
#
# },
# {
# "title": "쿠팡파트너스 <b>API</b> Key 발급 <b>방법</b> 및 쿠팡링크 우회 <b>방법</b>... ",
# "link": "https:\/\/blog.naver.com\/inam6?Redirect=Log&logNo=222198134315",
# "description": "쿠팡파트너스 <b>API</b> 키 <b>신청방법</b>을 간단히 설명 드리자면, 우선 자신의 블로그(<b>네이버</b> 및 기타 블로그)에 내 블로그에 등록할 쿠팡파트너스 상품의 링크가 포함된 글을 작성 한 뒤, 지인에게 부탁해 내가 쓴 글의... ",
# "bloggername": "럭키대디의 디지털 노마드",
# "bloggerlink": "https://blog.naver.com/inam6",
# "postdate": "20210106"
#
# },
# {
# "title": "쿠팡파트너스 크롬 확장 프로그램",
# "link": "https:\/\/blog.naver.com\/poem1979?Redirect=Log&logNo=222198099180",
# "description": "분이 계시다면 해당 링크를 공유해드리는 것이 더 좋은 <b>방법</b>일 듯 싶습니다. 저는 그동안 얼마의 수익을 올렸을까요? 치킨은 먹을 수 있겠습니다. 다음에 수익 공개를... <b>API</b>도 <b>신청</b>해놨는데 연락이 없네...",
# "bloggername": "CRITICAL POINT",
# "bloggerlink": "https://blog.naver.com/poem1979",
# "postdate": "20210106"
#
# },
# {
# "title": "가상화폐 관련 사이트 모음",
# "link": "https:\/\/blog.naver.com\/fmsf_xcdd60245?Redirect=Log&logNo=222197988292",
# "description": "com/vpnschool/ ) - VPN 정보 커뮤니티, PPTP, 제작, 일상이야기 제공, <b>네이버</b> 카페. - 코인네스트... - 바이낸스 (binance) 해외 거래소 가상화폐 가입 <b>방법</b> 바이낸스 가입.토큰포스트( http://www.... ",
# "bloggername": "ᙨ알트그룹다이 ᑌ",
# "bloggerlink": "https://blog.naver.com/fmsf_xcdd60245",
# "postdate": "20210106"
#
# },
# {
# "title": "&quot;부동산 창업 준비&quot;",
# "link": "https:\/\/blog.naver.com\/my1sthouse?Redirect=Log&logNo=222197147398",
# "description": "1) 상가 분양주가 분양대금 잔금을 치르고,,등기가 분양주로 이전된 후에 등록증을 <b>신청</b>하는 <b>방법</b>.... 1) 전화번호 - 전화번호1개, 팩스 1개, (KT의 <b>API</b> 서비스 <b>신청</b>하여 한방/전화 연동하여 사용) 2) <b>네이버</b>부동산... ",
# "bloggername": "미드카운티 다이아부동산",
# "bloggerlink": "https://blog.naver.com/my1sthouse",
# "postdate": "20210105"
#
# },
# {
# "title": "티스토리의 쿠팡파트너스 링크 일시 제거 알림",
# "link": "https:\/\/blog.naver.com\/yconcei2440?Redirect=Log&logNo=222196626061",
# "description": "가입 <b>신청</b>이 승인된건 9일이였어요!! 그런데 사실 투잡을 한다는 게 말처럼 쉬운게 아니거든요 웹사이트로 빠지게 해버려 조회수가 나오지 않은 경험을 했습니다. 현실적인 수익을 낼수있는 <b>방법</b>에 대해... ",
# "bloggername": "안녕, 요코",
# "bloggerlink": "https://blog.naver.com/yconcei2440",
# "postdate": "20210105"
#
# },
# {
# "title": "한 해를 돌아보며 (1)",
# "link": "https:\/\/blog.naver.com\/adler0912?Redirect=Log&logNo=222195597596",
# "description": "꿈에 체계적으로 다가가는 <b>방법</b>과 시간 낭비를 줄이는 <b>방법</b>을 배운 유익한 경험이었다. 7. 삼성전자... 코딩 독학 <b>네이버</b> 부스트코스, 유튜브 등을 통해 코딩을 독학했다. 카카오 오픈 <b>API</b>를 통해 공부하면서... ",
# "bloggername": "靑",
# "bloggerlink": "https://blog.naver.com/adler0912",
# "postdate": "20210104"
#
# },
# {
# "title": "카페24 쇼핑몰 수정 <b>네이버</b> 카카오로그인 작업 의뢰",
# "link": "https:\/\/blog.naver.com\/yconcei2440?Redirect=Log&logNo=222195522858",
# "description": "홈&amp;쇼핑 어플 카카오톡으로 간편 로그인 <b>방법</b>입니다! 초보 유튜버의 영상이 참신한 콘텐츠가 아니면... 내 카카오 계정으로 로그인해서 없으면 회원가입 한 후 로그인해서 필요함 <b>API</b> 를 선택해서 <b>신청</b>합니... ",
# "bloggername": "안녕, 요코",
# "bloggerlink": "https://blog.naver.com/yconcei2440",
# "postdate": "20210104"
#
# },
# {
# "title": "[키움 영웅문 캐치 조건식 공부] 볼린저밴드(Bolinger Band)",
# "link": "https:\/\/blog.naver.com\/whistle1119?Redirect=Log&logNo=222194526965",
# "description": "자세한 내용은 <b>네이버</b> 검색하시면 엄청나게 나오는데 어떤 원리인지 살짝만 맛만보자구요.... 바쁘고 매매하기 어려운분들은 기준봉을 이용한 엑셀 <b>API</b> 자동매매를 한번 느껴보세요. ■ 강의<b>신청</b> 문의사항... ",
# "bloggername": "Stock Whistle",
# "bloggerlink": "https://blog.naver.com/whistle1119",
# "postdate": "20210103"
#
# },
# {
# "title": "[이벤트] 플희타로, 새해 복 많이 받으세요~^^,새해인사",
# "link": "https:\/\/blog.naver.com\/wkdi3352?Redirect=Log&logNo=222192114588",
# "description": "(이웃<b>신청</b> 하시면 됩니다ㅋㅋㅋ) ㅡ 이벤트 참여<b>방법</b> ㅡ 참여의사 댓글 달기! (1.1일ㅡ1.2일까지)... ㅡ <b>네이버</b> OGQ이모티콘 아래 6개 중 1개 http://<b>api</b>.market.ogq.me/account/iv/21063 ㅡ 당첨자발표 ㅡ 총 5분의... ",
# "bloggername": "비밀을 간직한 여자, 플희",
# "bloggerlink": "https://blog.naver.com/wkdi3352",
# "postdate": "20210101"
#
# },
# {
# "title": "태그 목록",
# "link": "https://junho85.pe.kr/tag",
# "description": "JavaMail 층간소음 각성 주문 study LCD 소니 자동차 <b>네이버</b> 프렌즈타운 ansible TLS... 자동납부<b>신청</b> 온라인납부 언제쯤1000명넘을까 500명돌파 방탕일기 퓨젼요리 즉흥구매 전령신... ",
# "bloggername": "준호씨의 블로그",
# "bloggerlink": "https://junho85.pe.kr/",
# "postdate": "20210101"
#
# },
# {
# "title": "070이 아닌 번호로 국제전화를 유도하는 스미싱",
# "link": "https://wellbegin-halfdone.tistory.com/576",
# "description": "그리고 그 외로 은행을 가장해서 보안메일을 보내는 척, 악성코드를 심는 <b>방법</b>도 당하지는 않았어도... 결제 알림 메시지였는데, <b>네이버</b> 페이로 돈이 30만 원 가량 결제되었으니, 본인이 결제한 게 아니라면... ",
# "bloggername": "시작이 반이고픈 블로그",
# "bloggerlink": "http://wellbegin-halfdone.tistory.com/",
# "postdate": "20210101"
#
# },
# {
# "title": "[이렇게 사용하세요!] Cloud IoT Core 서비스와 Cloud Data... ",
# "link": "https:\/\/blog.naver.com\/n_cloudplatform?Redirect=Log&logNo=222189659581",
# "description": "이러한 장치 및 설비들은 시간의 경과 또는 사용자의 운용 <b>방법</b>에 따라 그 성능이... 상품 <b>신청</b> <b>네이버</b> 클라우드 플랫폼 접속 &gt; Console &gt; Cloud IoT Core &gt; Subscription * Cloud IoT Core는... ",
# "bloggername": "네이버 클라우드 플랫폼 (NAVER CLOUD PLATFORM)",
# "bloggerlink": "https://blog.naver.com/n_cloudplatform",
# "postdate": "20201231"
#
# },
# {
# "title": "반도체 공사관련 기업 실적추적",
# "link": "https:\/\/blog.naver.com\/donyon3?Redirect=Log&logNo=222190701491",
# "description": "오늘도 그 한 줄의 글 귀를 찾아 내기 위해 많은 투자자들이 구글과 <b>네이버</b>에 해당 기업명으로 검색을... 분석<b>방법</b>을 공유하겠다. 그리고 추가적으로 말씀드리자면 애드포스트 <b>신청</b>했다. 단순히 돈을 벌려고... ",
# "bloggername": "가치투기꾼의 기업분석",
# "bloggerlink": "https://blog.naver.com/donyon3",
# "postdate": "20201230"
#
# },
# {
# "title": "헛소리하는 AI스피커 영실이를 따라 해 봤다",
# "link": "https://brunch.co.kr/@businessinsight/68",
# "description": "이라는 <b>방법</b>을 쓴다는 것, 그리고 request문이 아닌 google.cloud라는 라이브러리를 썼다 는 점만 다르네요. * 본 과정의 진행순서 1. 구글 클라우드 플랫폼의 <b>API 신청</b>하여 환경변수 설정 2. 질문에 대한 대답... ",
# "bloggername": "돌망",
# "bloggerlink": "",
# "postdate": "20201230"
#
# },
# {
# "title": "아임웹(imweb) - 무료 랜딩페이지/홈페이지 만들기",
# "link": "https:\/\/blog.naver.com\/nonamelight1?Redirect=Log&logNo=222189679378",
# "description": "<b>네이버</b>랑 카카오에 입점<b>신청</b>도 가능하네요(제휴한듯) 5. 예약관리 홈페이지를 꼭 쇼핑몰에만... 홈페이지 제작 <b>방법</b>을 모르시거나 랜딩페이지가 필요하시거나 하신 분들은 클릭만 해도 손쉽게 만들 수 있는... ",
# "bloggername": "전문직과 IT의 만남",
# "bloggerlink": "https://blog.naver.com/nonamelight1",
# "postdate": "20201229"
#
# },
# {
# "title": "헛소리하는 AI스피커 영실이를 따라해 봤다",
# "link": "https:\/\/blog.naver.com\/wishket?Redirect=Log&logNo=222188097213",
# "description": "설정이라는 <b>방법</b>을 쓴다는 것만 다르네요. 영실이가 구글에게 * 본 과정의 진행순서 1. 구글 클라우드 플랫폼의 <b>API 신청</b>하여 환경변수 설정 2. 질문에 대한 대답문장을 구글 <b>API</b>를 활용하여mp3파일로 변환... ",
# "bloggername": "IT아웃소싱 플랫폼, 위시켓",
# "bloggerlink": "https://blog.naver.com/wishket",
# "postdate": "20201228"
#
# },
# {
# "title": "ESP32보드&amp;C언어를 이용한 오픈<b>API</b> 활용<b>방법</b>(feat. 코로나... ",
# "link": "https:\/\/blog.naver.com\/simjk98?Redirect=Log&logNo=222187055760",
# "description": "<b>API</b>를 말합니다. 공공데이터 포털에서 제공하고 있는 공공데이터 , 구글지도, <b>네이버</b>... 하는 <b>API</b>를 선택하여 활용<b>신청</b> 하시면 됩니다. 데이터를 가져오는 <b>방법</b>은 알았으니... ",
# "bloggername": "공은 여기에서 멈춘다. -해리 트루먼",
# "bloggerlink": "https://blog.naver.com/simjk98",
# "postdate": "20201227"
#
# },
# {
# "title": "파이썬을 이용하여 재무제표를 쉽게 다운로드해 보자!",
# "link": "https:\/\/blog.naver.com\/sleep0615?Redirect=Log&logNo=222186996431",
# "description": "첫 번째로는 <b>네이버</b> 금융을 사용하여, 간단하게 확인하는 <b>방법</b>이 있습니다. 아주... do 위의 페이지에 접속하여 회원가입 후, 인증키를 <b>신청</b>하시면 인증키를 받으실 수... ",
# "bloggername": "My Notebook",
# "bloggerlink": "https://blog.naver.com/sleep0615",
# "postdate": "20201227"
#
# },
# {
# "title": "가비아 주가, 좋은 호재 없이, 추락하는 이유는?",
# "link": "https:\/\/blog.naver.com\/andrew0604?Redirect=Log&logNo=222186979116",
# "description": "인증 <b>신청</b>을 완료했습니다. 가비아 g클라우드는 국내 기업의 실정에 맞춰 자체 스택으로 개발돼 기업의 추가적인 요구사항에도 유연한 기술 지원이 가능하다는 것이 특징이며... ",
# "bloggername": "학문은 사용할 때 비로소 빛이 난다",
# "bloggerlink": "https://blog.naver.com/andrew0604",
# "postdate": "20201227"
#
# },
# {
# "title": "회사소개_케어랩스(CARELABS)",
# "link": "https:\/\/blog.naver.com\/upgradekaie?Redirect=Log&logNo=222186867888",
# "description": "2000년대 들어 급속도로 인터넷 보급이 확산되면서 이용자 수가 동반 증가함에 따라 국내 대형 포털 업체(<b>네이버</b>, 카카오, 구글 등)의 검색 광고시장이 자리매김 할 수 있었으며, 디스플레이광고시장 또한 동반... ",
# "bloggername": "Outing with Ultimate freedom",
# "bloggerlink": "https://blog.naver.com/upgradekaie",
# "postdate": "20201227"
#
# },
# {
# "title": "쿠팡파트너스 하는법, 쿠팡파트너스 회원가입절차, AF7471709",
# "link": "https:\/\/blog.naver.com\/inam6?Redirect=Log&logNo=222184800201",
# "description": "<b>네이버</b> 검색창에 “쿠팡”이라고 입력하고 검색을 해주세요. 쿠팡회원가입<b>방법</b> 2. 그럼 아래 사진과... 통해 <b>API</b> 키를 <b>신청</b>해 승인을 받아야 하는데, 이것은 다음에 다루어 볼게요. 쿠팡 파트너스 회원가입 <b>방법</b>... ",
# "bloggername": "럭키대디의 디지털 노마드",
# "bloggerlink": "https://blog.naver.com/inam6",
# "postdate": "20201225"
#
# },
# {
# "title": "매일경제 20. 12. 23 수요일",
# "link": "https:\/\/blog.naver.com\/bindoong_e?Redirect=Log&logNo=222182706954",
# "description": "<b>네이버</b> 등 빅테크가 마이데이터 사업에 합류, 금융업 주도권을 둘러싼 경쟁도 치열해질 전망.... (주식투자에서) 주가 추세의 가속도를 측정해 변동 상황을 이해하는 하나의 <b>방법</b>. 주가 상승세에서는 모멘텀의... ",
# "bloggername": "행복은 나로부터",
# "bloggerlink": "https://blog.naver.com/bindoong_e",
# "postdate": "20201223"
#
# },
# {
# "title": "오픈마켓 등록상품을 쿠팡에 일괄 등록 <b>방법</b>(쿠팡 입점 <b>방법</b> 포함)",
# "link": "https:\/\/blog.naver.com\/forevertb?Redirect=Log&logNo=222182586110",
# "description": "1) <b>네이버</b>에 쿠팡 판매자 또는 쿠팡 마켓플레이스 검색해서 &quot;쿠팡 마켓플레이스&quot; 클릭 2) 입점 <b>신청</b>하... <b>API</b> 연동용 판매자 ID 및 도메인 ID 발급<b>방법</b>은 다음을 참조해 주세요! 1) <b>API</b> 연동용 판매자 ID 도메인... ",
# "bloggername": "Just Do it",
# "bloggerlink": "https://blog.naver.com/forevertb",
# "postdate": "20201223"
#
# },
# {
# "title": "디지털 채널 재구축 완성으로 혁신에 한 발 더",
# "link": "https:\/\/blog.naver.com\/fneplus?Redirect=Log&logNo=222180463859",
# "description": "고객 로그인 시 개인별 맞춤형 콘텐츠가 제공되며, 카드<b>신청</b> 시 <b>신청</b>정보 자동 채우기(Fill-in), <b>신청</b>서... ▷우리카드 디지털 채널이 플랫폼사로서 <b>네이버</b>, 카카오 등 플랫폼 대비 차별성이나 강점은? A)... ",
# "bloggername": "금융경제플러스",
# "bloggerlink": "https://blog.naver.com/fneplus",
# "postdate": "20201221"
#
# },
# {
# "title": "[2020.12.20 15:02] 22일부터 농협·신협·증권사도... ",
# "link": "https:\/\/blog.naver.com\/banks?Redirect=Log&logNo=222179765571",
# "description": "핀테크업체를 통해 이용하는 <b>방법</b>도 있다. <b>네이버</b>페이· 카카오페이·토스 등에서 오픈뱅킹에... 구독<b>신청</b> 지면 구독<b>신청</b> ⓒ 한경닷컴, 무단전재 및 재배포 금지 No.... ",
# "bloggername": "블록장생",
# "bloggerlink": "https://blog.naver.com/banks",
# "postdate": "20201220"
#
# },
# {
# "title": "조건검색 주식자동매매프로그램이 특별한 이유",
# "link": "https:\/\/blog.naver.com\/ok1004okok?Redirect=Log&logNo=222178912348",
# "description": "쓰이는 <b>방법</b>입니다. 모의투자를 하기 위해 조건검색을 활용하자 모의투자를 해보기로 마음먹고 키움증권사에 주식 계좌를 만들고, <b>신청</b>한 뒤에 HTS(Home Trading System, 집이나 사무실 등 PC를 통하여 거래하는... ",
# "bloggername": "번개트레이더 네이버 공식 블로그",
# "bloggerlink": "https://blog.naver.com/ok1004okok",
# "postdate": "20201219"
#
# },
# {
# "title": "처음부터 배우는 딥러닝 챗봇 4회차 리뷰_한빛미디어",
# "link": "https:\/\/blog.naver.com\/activeup?Redirect=Log&logNo=222178781652",
# "description": "사용하는 <b>방법</b>에 대하여 학습합니다. - 카카오톡 채널 가입 - 카카오 아이 오픈빌더 OBT <b>신청</b> - 봇 생성... 연동하는 <b>방법</b>에 대하여 설명합니다. <b>네이버</b>톡톡 챗봇 플랫폼은 봇을 만드는데 필요한 Chat Bot <b>API</b>를... ",
# "bloggername": "IT와 캠핑 함께하는 힐링",
# "bloggerlink": "https://blog.naver.com/activeup",
# "postdate": "20201219"
#
# },
# {
# "title": "2020년 12월 18일 금요일 신문브리핑",
# "link": "https://lhw9910.tistory.com/entry/2020%EB%85%84-12%EC%9B%94-18%EC%9D%BC-%EA%B8%88%EC%9A%94%EC%9D%BC-%EC%8B%A0%EB%AC%B8%EB%B8%8C%EB%A6%AC%ED%95%91",
# "description": "ai로 <b>신청</b>하시기 바랍니다. 랜딩 : http://moya.ai 모바일 App : http://app.moya.ai 대시보드 : https://watch.... 기자 <b>네이버</b>가 국내 운영 글로벌 IT기업 백여곳보다 2배 가까이 많은 세금을 낸 것이다. 국내... ",
# "bloggername": "블로그",
# "bloggerlink": "http://lhw9910.tistory.com/",
# "postdate": "20201218"
#
# },
# {
# "title": "2020년 12월 17일 목요일 신문브리핑",
# "link": "https://ilsang2.tistory.com/570",
# "description": "윤 총장은 이르면 오늘 행정법원에 징계 처분에 대한 취소소송과 함께 집행정지를 <b>신청</b>할 예정입니다. ■ 윤석열 검찰총장에 대한 중징계에 대해 여야 정치권 반응은 크게 엇갈렸습니다. 더불어민주당은... ",
# "bloggername": "세상 모든 것들에 관한 수다",
# "bloggerlink": "http://ilsang2.tistory.com/",
# "postdate": "20201217"
#
# },
# {
# "title": "<b>네이버</b> 단축 URL <b>API 신청</b>하기, 애플리케이션 등록",
# "link": "https:\/\/blog.naver.com\/ybt0314?Redirect=Log&logNo=222175386181",
# "description": "등록, <b>네이버</b> 단축 URL <b>API 신청</b>하는 <b>방법</b>을 정리해보려 한다. 파이썬으로 <b>네이버</b> 단축 URL(me2.do) <b>API</b>를 사용해서 쿠팡 파트너스 URL 주소를 <b>네이버</b> 단축 URL로 변경해봤는데 이를 사용하기 위해선... ",
# "bloggername": "유별난n잡러",
# "bloggerlink": "https://blog.naver.com/ybt0314",
# "postdate": "20201216"
#
# },
# {
# "title": "[강연] 2020 데이터 그랜드 컨퍼런스",
# "link": "https:\/\/blog.naver.com\/zakhar?Redirect=Log&logNo=222175156484",
# "description": "[Key Note#1] 이진규 개인정보보호 책임자 cpo/<b>네이버</b> &lt;데이터 제도 변화에 따른 데이터 경제 전망과... 결합구독 <b>신청</b>시 할인 제시, 해지사유 VoC 분석하여 기업에 Intelligence 제시 등등으로 서비스 발전 가능 2)... ",
# "bloggername": "기록, 지금",
# "bloggerlink": "https://blog.naver.com/zakhar",
# "postdate": "20201216"
#
# },
# {
# "title": "#2020. 12. 12(토) #따뜻한 #세상 #이야기",
# "link": "https:\/\/blog.naver.com\/sss6510?Redirect=Log&logNo=222171086559",
# "description": "기피 <b>신청</b>… 공판 미뤄져 ■방용훈, 故장자연 前소속사 대표 재판서 증인 불출석 ■검찰, '5·18... 출처 : 이데일리 | <b>네이버</b> - http://naver.me/xXQ2Vpeo 기타 파주·울산·천안 '규제지역' 지정 저울질... ",
# "bloggername": "신성수 건설안전",
# "bloggerlink": "https://blog.naver.com/sss6510",
# "postdate": "20201212"
#
# },
# {
# "title": "메지온 주주방 12월 11일 #2",
# "link": "https:\/\/blog.naver.com\/gildongmo?Redirect=Log&logNo=222171069048",
# "description": "-&gt; 별별별: 참 사람 인내심 시험하는<b>방법</b>도 가지가지군요. -&gt; 메기옥: 확정 되면 낸다던 정정공시를... 공시는 이전에 3개월 내에 <b>신청</b>하겠다는 걸 못 지켜서 그에 대한 공시일 뿐인데 확대해석 노노입니다.... ",
# "bloggername": "길동모",
# "bloggerlink": "https://blog.naver.com/gildongmo",
# "postdate": "20201212"
#
# },
# {
# "title": "홈페이지제작전문 랭크업 소개합니다.",
# "link": "https:\/\/blog.naver.com\/lovelyhwa2020?Redirect=Log&logNo=222170724591",
# "description": "모바일 홈페이지 지도<b>API</b> 제공 해드립니다. 개인 인터넷 창업이나 개인 방송등을 하다보면 시간과 비용이 만만치 않게 들고 아이템은 좋아도 어떠한 절차와 <b>방법</b>으로 홈페이지를 개설해야 할지 갈피를 못잡는... ",
# "bloggername": "나의 빛나는 사계절♥️",
# "bloggerlink": "https://blog.naver.com/lovelyhwa2020",
# "postdate": "20201211"
#
# },
# {
# "title": "제5차 「디지털금융 협의회」 개최- 디지털금융 규제·제도... ",
# "link": "https:\/\/blog.naver.com\/higer31?Redirect=Log&logNo=222169115503",
# "description": "최인혁 <b>네이버</b>파이낸셜 대표, 류준우 보맵 대표 ․(전문가) 정준혁 서울대교수, 최미수... *혁신금융서비스 <b>신청</b>시 적극 검토·지정(수시), 제도 개선 방안 등 검토(‘21.上) &lt; 기대 효과 (음식 주문 중개 폴랫폼... ",
# "bloggername": "하이거",
# "bloggerlink": "https://blog.naver.com/higer31",
# "postdate": "20201210"
#
# },
# {
# "title": "2020년 12월 10일 목요일 신문을 통해 알게 된 것들... ",
# "link": "https:\/\/blog.naver.com\/leeih0077?Redirect=Log&logNo=222168964819",
# "description": "‘재판관 후즈후’, ‘연<b>방법</b>관 연감’ → 각 日, 美의 판사 정보집. 민간이 만들어 유료판매 된다고.... 격리 면제 <b>신청</b>하다 결국 실패...하루에 1000만원 손실 '한숨' ☞ 내년엔 잘못 보낸 내 돈 돌려준다..... ",
# "bloggername": "이인희와 함께 만들어가는 인재가 희망인 세상!!!",
# "bloggerlink": "https://blog.naver.com/leeih0077",
# "postdate": "20201210"
#
# },
# {
# "title": "12월 10일 모야(MoYa) 데일리 뉴스 모음 (인공지능,핀테크... ",
# "link": "https:\/\/blog.naver.com\/dpszeagal33?Redirect=Log&logNo=222168844800",
# "description": "<b>네이버</b>클라우드-건양대, 의료 AI 인재 육성 위해 맞손 2020-12-09 22:36:00 이진영 기자 또 기술 지원과 교직원 및 재학생을 대상으로 한 클라우드 컴퓨팅 서비스 교육을 지원할 예정이다. <b>네이버</b>클... ",
# "bloggername": "현명한 의사결정을 위한 꿀정보",
# "bloggerlink": "https://blog.naver.com/dpszeagal33",
# "postdate": "20201210"
#
# },
# {
# "title": "검색광고마케터 1급 요약 정리 2_2 (요약 파일 有)",
# "link": "https:\/\/blog.naver.com\/vooww?Redirect=Log&logNo=222167872270",
# "description": "사용자 패턴분석 및 매체믹스 <b>네이버</b> 초기화면에 노출되는 타임보드는 별도 타기팅 없이 <b>네이버</b>에... ① 경쟁사 파악 첫 번째 파악 <b>방법</b>은 동일 카테고리의 다른 브랜드. 나이키와 아디다스, 요기요와... ",
# "bloggername": "Being independent.",
# "bloggerlink": "https://blog.naver.com/vooww",
# "postdate": "20201209"
#
# },
# {
# "title": "정보 환율조회 날짜별 환율",
# "link": "https:\/\/blog.naver.com\/pyw1327?Redirect=Log&logNo=222167485803",
# "description": "구속영장<b>신청</b> #AMD주가 #니케이지수 #디지털화폐 #마라톤 #반도체관련주 #AI관련주 #주식분석... 환불<b>방법</b> #증권사<b>API</b> #블록틱스 #가상화폐거래 #비트코인해외거래소 #블록체인기업 #비트코인주소 #모네로코인... ",
# "bloggername": "pyw1327님의블로그",
# "bloggerlink": "https://blog.naver.com/pyw1327",
# "postdate": "20201209"
#
# },
# {
# "title": "디지털금융 &amp; 민간인증서 &amp; 콜스 &amp; 마이데이터 &amp; 전기차 신시장... ",
# "link": "https:\/\/blog.naver.com\/oohehe77?Redirect=Log&logNo=222167332214",
# "description": "예비허가 <b>신청</b>을 접수, 29개사에 대한 본허가 심사가 진행되고 있다. 새해 1월에 본허가가 발표되면 8월부터 사전에 표준화한 전산상 정보 제공 방식인 마이데이터 표준 응용프로그램개발환경(<b>API</b>)에 의한... ",
# "bloggername": "트렌드 금융 부동산",
# "bloggerlink": "https://blog.naver.com/oohehe77",
# "postdate": "20201208"
#
# },
# {
# "title": "2020 클라우드컴퓨팅 전문인력 양성사업 교육받고 IT 인재되기!",
# "link": "https:\/\/blog.naver.com\/tekim1208?Redirect=Log&logNo=222167090390",
# "description": "&quot;정보화 시대와 클라우드 기술&quot; <b>네이버</b> 클라우드를 사용해보신 분들이라면 이 기술에 쉽게 이해하실 수... 개념부터 기본 활용 <b>방법</b>까지 차근차근 훈련할 수 있도록 하여 세부 교육 내용을 구성하였습니다.... ",
# "bloggername": "히토리 라이프스타일",
# "bloggerlink": "https://blog.naver.com/tekim1208",
# "postdate": "20201208"
#
# },
# {
# "title": "<b>네이버</b> 클라우드 플랫폼의 SMS 전송 <b>API</b> 설정하기",
# "link": "https:\/\/blog.naver.com\/vagabond-k?Redirect=Log&logNo=222165593639",
# "description": "그래서 새로운 SMS 전송 <b>API</b> 서비스를 찾았는데, <b>네이버</b> 클라우드 플랫폼의 많은 서비스들 중 하나를... 파란색의 '이용 <b>신청</b>하기' 버튼을 클릭하면 일단 회원 가입부터 하라고 나온다. 나는 일단 개인... ",
# "bloggername": "Vagabond K's Anything Factory",
# "bloggerlink": "https://blog.naver.com/vagabond-k",
# "postdate": "20201207"
#
# },
# {
# "title": "2020년 12월 2주차 창업 및 스타트업 소식 및 일정 정리 (뉴스... ",
# "link": "https:\/\/blog.naver.com\/leeks219?Redirect=Log&logNo=222165555974",
# "description": "지원사업 <b>신청</b> 공고 ⇒ Link ◾ KOTRA, NAVER 실시간 수출 전문서비스 지원사업 참여기업 모집... 유치<b>네이버</b>, 물류-디지털헬스 스타트업 2곳에 투자요즈마, K-Global 참여 스타트업 5곳에 시드... ",
# "bloggername": "강서기의 얼리어답터 리뷰 블로그",
# "bloggerlink": "https://blog.naver.com/leeks219",
# "postdate": "20201207"
#
# },
# {
# "title": "웹사이트 소프트웨어 맞춤설정하기",
# "link": "http://blog.daum.net/bumin2100/535",
# "description": "Google <b>API</b> Console Google Cloud Platform Console Google Play Console Firebase Console Actions on Google Console Cast... 글 <b>네이버</b> 애드포스트 <b>신청 방법</b>, 수익은 얼마나? (0) 2020.12.13 YouTube 광고로 수익을 창출할... ",
# "bloggername": "조은날,",
# "bloggerlink": "http://blog.daum.net/bumin2100",
# "postdate": "20201206"
#
# },
# {
# "title": "코로나가 앞당긴 디지털 전환, &lt;온택트 경영학&gt;",
# "link": "https:\/\/blog.naver.com\/awesome_ssa?Redirect=Log&logNo=222163917516",
# "description": "평소에도 기업을 경영하는 <b>방법</b>에 관심이 많아 세계 대표적인 기업들의 책을 즐겨 읽는 편인데... 서평단 모집을 하기에 바로 서평단 <b>신청</b>을 했고 선정된 덕분에 책을 지원받아 읽을 수 있게 되었다. - 와... ",
# "bloggername": "꾸준한 날들의 기록",
# "bloggerlink": "https://blog.naver.com/awesome_ssa",
# "postdate": "20201205"
#
# },
# {
# "title": "따라 하면서 마스터하는 네트워크와 네트워크 보안 2/e - 실무로... ",
# "link": "https:\/\/blog.naver.com\/zpdl92?Redirect=Log&logNo=222163632512",
# "description": "EIGRP <b>네이버</b> 관계 검증 ____9) EIGRP Passive 인터페이스 ____10) EIGRP SIA ____11) EIGRP Unequal 부하 분산 __3.... 설정 <b>방법</b> ____7) BGP 속성 ____8) BGP 속성별 기능 ____9) IGP와 BGP 동기 ____10) BGP 넥스트홉 ____11) 루트... ",
# "bloggername": "예수님 사랑합니다.",
# "bloggerlink": "https://blog.naver.com/zpdl92",
# "postdate": "20201205"
#
# },
# {
# "title": "[Dart 오픈 <b>Api</b>] 2020ver. 파이썬으로 dart 재무제표 크롤링 (3)... ",
# "link": "https:\/\/blog.naver.com\/yerin_flora?Redirect=Log&logNo=222159799347",
# "description": "apiKey <b>신청방법</b> import requests import json import pandas as pd <b>api</b>_key = 'your_<b>api</b>_key' 2.... 자꾸 <b>네이버</b>가 아니라 NAVER라 하는 이유는 &quot;<b>네이버</b>&quot;라 하면 안나옴ㅋ NAVER가 공식... ",
# "bloggername": "녜린이네 블로그",
# "bloggerlink": "https://blog.naver.com/yerin_flora",
# "postdate": "20201201"
#
# },
# {
# "title": "[월간] 11월의 토끼물생활",
# "link": "https:\/\/blog.naver.com\/blackshadowrabbit?Redirect=Log&logNo=222159439183",
# "description": "직접적인 혜택은 <b>네이버</b> 맴버쉽 플러스 12개월 무료! 이거 상당히 좋은데 일단 이건 논외로.... (가끔 제가 먼저 <b>신청</b>하기도 하지만요) 서이웃분들의 포스팅은 좋아요나 댓글을 달지 않더라도 가급적... ",
# "bloggername": "책상 위 작은 어항",
# "bloggerlink": "https://blog.naver.com/blackshadowrabbit",
# "postdate": "20201201"
#
# },
# {
# "title": "2020년 12월 경제 뉴스레터 요약",
# "link": "https:\/\/blog.naver.com\/mattlanter?Redirect=Log&logNo=222159308327",
# "description": "- 공공분양 아파트는 주변 시세와 매우 근접하게, 그러나 꾸준히 계속 공급하는 것이 주택 가격 안정시키는 좋은 <b>방법</b>. 지금까지는 공공분양 아파트 저렴하게 공급해야 한다는 것이 관행이었음.... ",
# "bloggername": "께롱이의 햄보칸 일상",
# "bloggerlink": "https://blog.naver.com/mattlanter",
# "postdate": "20201201"
#
# },
# {
# "title": "쇼핑몰 [통합 솔루션] 업체 완전정복, 8편→[샵플링]",
# "link": "https:\/\/blog.naver.com\/advisor1?Redirect=Log&logNo=222158855243",
# "description": "내 상품도 팔고, 다른 상품도 팔고 [전문셀러 전용메뉴] <b>네이버</b> 스마트스토어판매자를 위한 해시태그... 통합버전으로, [라이트]는 15만 원 [베이직]은 20만 원 (그 이상은 관심 없음!) (사용료 및 서비스 <b>신청</b>... ",
# "bloggername": "위기탈출-돈가이버!",
# "bloggerlink": "https://blog.naver.com/advisor1",
# "postdate": "20201130"
#
# },
# {
# "title": "2020.11.30 월",
# "link": "https:\/\/blog.naver.com\/gmlwls212121?Redirect=Log&logNo=222158343807",
# "description": "현대차그룹-<b>네이버</b>, '미래 모빌리티' 손 잡았다…협업 본격화 ● 현대·기아차, 美... 전쟁…<b>네이버</b>·빅히트에 NC 가세 ● 10월 주식·회사채 발행 19.7% 증가…빅히트 등 IPO 효과 ● 외인 순매수... ",
# "bloggername": "☆소확행 - 샛별이 일상이야기☆",
# "bloggerlink": "https://blog.naver.com/gmlwls212121",
# "postdate": "20201130"
#
# },
# {
# "title": "20.11.30(월)_장전 브리핑",
# "link": "https:\/\/blog.naver.com\/company_bb?Redirect=Log&logNo=222158172105",
# "description": "현대차그룹-<b>네이버</b>, '미래 모빌리티' 손 잡았다…협업 본격화 ● 현대·기아차, 美... 베스트바이 3분기 매출 21% 급증 '25년 만에 최고' ● 인텔, CPU·GPU·FPGA통합 소프트웨어 '원<b>API</b>' 출시...'인텔칩... ",
# "bloggername": "Company BigBrother",
# "bloggerlink": "https://blog.naver.com/company_bb",
# "postdate": "20201130"
#
# },
# {
# "title": "MyData란 무엇인가, 마이데이터 사업은?",
# "link": "https:\/\/blog.naver.com\/dpszeagal33?Redirect=Log&logNo=222158109218",
# "description": "법에 구체적인 전송방식은 표현돼 있지 않지만 많은 이들은 이 <b>방법</b>으로 오픈<b>API</b>를 말합니다. 표준화... 지방은행 중에는 경남은행이 <b>신청</b>했다. <b>네이버</b>(<b>네이버</b>파이낸셜)와 카카오(카카오페이), NHN(NHN페이코) 등... ",
# "bloggername": "현명한 의사결정을 위한 꿀정보",
# "bloggerlink": "https://blog.naver.com/dpszeagal33",
# "postdate": "20201130"
#
# },
# {
# "title": "1. 워드프레스 입문자 호스팅 종결. 무조건 클라우드호스팅... ",
# "link": "https:\/\/blog.naver.com\/abofam?Redirect=Log&logNo=222157828597",
# "description": "<b>네이버</b> 메일 저장공간이 5기가 입니다. 아래 보세요. 웹사이트는 접속자 입장에서 속도가 중요하기... 개발자라면 관리형 클라우드 호스팅 플랫폼을 기반으로 통합, 자동화 개발에 <b>API</b>를 사용할 수... ",
# "bloggername": "ART HANDS 예손",
# "bloggerlink": "https://blog.naver.com/abofam",
# "postdate": "20201129"
#
# },
# {
# "title": "아마존",
# "link": "https:\/\/blog.naver.com\/sooji2?Redirect=Log&logNo=222156402207",
# "description": "또 같은 해에 '원클릭(One Click) 주문'에 대한 특허를 <b>신청</b>했다. 이 원클릭 주문 시스템은 고객의... 또한 같은 해인 2002년 아마존은 자사의 데이터 베이스와 서비스를 오픈 <b>API</b>(Open Application Program... ",
# "bloggername": "지식 & 문화충전소",
# "bloggerlink": "https://blog.naver.com/sooji2",
# "postdate": "20201127"
#
# },
# {
# "title": "마케팅 때문에 고민입니다.",
# "link": "https:\/\/blog.naver.com\/zealot0192?Redirect=Log&logNo=222154643674",
# "description": "<b>네이버</b>에서는 'modoo'라고 하는 무료 홈페이지 솔루션도 제공하고 있으니 경험하기엔 그 정도로 시작해... 브랜딩 요소를 강화하는 데는 어떤 <b>방법</b>들이 있을까요? 전통적인 <b>방법</b>은 국가기관 등으로부터 받는... ",
# "bloggername": "책읽고 있습니다",
# "bloggerlink": "https://blog.naver.com/zealot0192",
# "postdate": "20201126"
#
# },
# {
# "title": "사이트 검색광고 전략으로 보고서를 활용하는 <b>방법</b>은 다차원... ",
# "link": "https:\/\/blog.naver.com\/easthof?Redirect=Log&logNo=222154904647",
# "description": "- 광고비용 보고서 : 클릭초이스, 브랜드 검색, 클릭초이스 플러스, 상품광고 등 <b>네이버</b> 검색광고 상품을 이용하여 지불한 광고비 정보를 제공합니다. 지금까지 보고서 메뉴의 활용 <b>방법</b>에 대해 알아봤습니다.... ",
# "bloggername": "안조아를 조아로 동쪽에희망",
# "bloggerlink": "https://blog.naver.com/easthof",
# "postdate": "20201126"
#
# },
# {
# "title": "[LINK] 구글 서치 콘솔(Google Search console) – 구글을... ",
# "link": "http://hyunsik.me/wordpress/?p=14573",
# "description": "툴, <b>네이버</b> SEO [LINK] 사운드클라우드(SoundCloud) – 음원 공유 사이트 / 다운로드 <b>방법</b> [LINK] 청약홈 – 주택 분양 정보 / 청약 <b>신청</b> 사이트 [LINK] 카카오 애드핏 – 어디에나 붙일 수 있는... ",
# "bloggername": "현식로그",
# "bloggerlink": "http://hyunsik.me/wordpress",
# "postdate": "20201126"
#
# },
# {
# "title": "대신증권 크레온 수수료 총 정리",
# "link": "https:\/\/blog.naver.com\/woncheolcho?Redirect=Log&logNo=222153935636",
# "description": "한 가지 더, 크레온은 다른 증권사들과 다르게 수수료를 알아보는 <b>방법</b>이 다릅니다. 아래 그림을 봐주세요. 크레온은 홈페이지 내부에서만 수수료를 확인할 수 있다. 다른 증권사들은 <b>네이버</b>에 검색하면 바로... ",
# "bloggername": "Welcome to SnowBall",
# "bloggerlink": "https://blog.naver.com/woncheolcho",
# "postdate": "20201125"
#
# },
# {
# "title": "코로나19로 인한 비대면 시대에서 살아남는 재테크의 비밀",
# "link": "https:\/\/blog.naver.com\/ok1004okok?Redirect=Log&logNo=222148735192",
# "description": "우리는 이미 <b>방법</b>을 알고있습니다. 이 시대에서 살아남는 <b>방법</b>을 말이죠. 바로 재테크입니다. 재테크는... 제공되며 <b>API</b>에 변경된 사항을 신속하게 대응하는 빠른 업데이트도 지원합니다. - 지금 <b>네이버</b>... ",
# "bloggername": "번개트레이더 네이버 공식 블로그",
# "bloggerlink": "https://blog.naver.com/ok1004okok",
# "postdate": "20201124"
#
# },
# {
# "title": "[지원사업안내] 2020 NH디지털혁신캠퍼스 챌린지 온라인... ",
# "link": "https:\/\/blog.naver.com\/startup_nvsc?Redirect=Log&logNo=222152054812",
# "description": "hwp 파일 다운로드 ※ 참가분야에 따라 &quot;참가분야명_참가<b>신청</b>서(팀명)&quot;으로 제출 ■ <b>신청방법</b>... 카카오오픈채팅, <b>네이버</b>밴드를 통해 접속 <b>방법</b> 고지할 예정 ※ 사전교육 관련 자료 첨부파일... ",
# "bloggername": "낙성벤처창업센터",
# "bloggerlink": "https://blog.naver.com/startup_nvsc",
# "postdate": "20201123"
#
# },
# {
# "title": "[상품소개] 클로바 스피치(CLOVA Speech) 사용하기",
# "link": "https:\/\/blog.naver.com\/n_cloudplatform?Redirect=Log&logNo=222152002544",
# "description": "<b>API</b> 호출 방식을 통한 인식 작업 요청 다음으로 CLOVA Speech <b>API</b> 호출 URL로 음성 인식을 할 원본 파일을 보내고, 엔진에서 처리한 결과값을 json 형태로 리턴받는 <b>방법</b>입니다. 1. 먼저 CLOVA Speech 서비스... ",
# "bloggername": "네이버 클라우드 플랫폼 (NAVER CLOUD PLATFORM)",
# "bloggerlink": "https://blog.naver.com/n_cloudplatform",
# "postdate": "20201123"
#
# },
# {
# "title": "오픈마켓상품등록<b>방법</b>",
# "link": "https://whtips.com/archives/%EC%98%A4%ED%94%88%EB%A7%88%EC%BC%93%EC%83%81%ED%92%88%EB%93%B1%EB%A1%9D%EB%B0%A9%EB%B2%95/",
# "description": "잔망킹 #위탁판매 #온라인쇼핑몰 드디어 #12 <b>네이버</b> 스마트 스토어 / 옥션 / 지마켓... 컨설턴트가 직접 찾아가 필요한 서류준비와 <b>신청</b>절차, 상품등록 , 운영 <b>방법</b> 도 꼼꼼하게... ",
# "bloggername": "우먼헬스",
# "bloggerlink": "https://whtips.com/",
# "postdate": "20201121"
#
# },
# {
# "title": "부동산 시장분석, 국토부 고시 실거래가 수집 - 전월세편",
# "link": "https:\/\/blog.naver.com\/o12486vs2?Redirect=Log&logNo=222149329168",
# "description": "쉬운 <b>방법</b>일 겁니다. 국토부고시 실거래가는<b>네이버</b> 부동산에서 보았던 것들이 있습니다.... 그럼 필요한 것을 우선 해야겠죠 <b>api</b>활용<b>신청</b>부터 하고 <b>api</b>키를 발급받아야 합니다.... ",
# "bloggername": "으뜸이네",
# "bloggerlink": "https://blog.naver.com/o12486vs2",
# "postdate": "20201120"
#
# },
# {
# "title": "[LINK] <b>네이버</b> 서치어드바이저 – 웹 표준 체크 툴, <b>네이버</b>... ",
# "link": "http://hyunsik.me/wordpress/?p=14421",
# "description": "0 : <b>네이버</b> 검색 <b>API</b> 활용 워드프레스 플러그인 2010-02-28 In &quot;Computer&quot; <b>네이버</b>의 뉴스... 다운로드 <b>방법</b> [LINK] 청약홈 – 주택 분양 정보 / 청약 <b>신청</b> 사이트 [LINK] 카카오 애드핏... ",
# "bloggername": "현식로그",
# "bloggerlink": "http://hyunsik.me/wordpress",
# "postdate": "20201120"
#
# },
# {
# "title": "직원명의블로그 이전 문제, 단체아이디전환으로 해결하기",
# "link": "https:\/\/blog.naver.com\/project3010?Redirect=Log&logNo=222148648553",
# "description": "구체적인 <b>방법</b>에 대해 알아보겠습니다. 직원명의블로그 대표자명의로 변경하는법 2단계 1. 직원명의아이디를 단체아이디 전환 <b>신청</b>한다. <b>네이버</b>에서는 단체에서 사용할 목적으로 만든 아이디가 개인아이디일... ",
# "bloggername": "마케팅하는 디자이너",
# "bloggerlink": "https://blog.naver.com/project3010",
# "postdate": "20201119"
#
# },
# {
# "title": "NH디지털혁신캠퍼스 챌린지 온라인 해커톤 참가팀 모집 (~12.9)",
# "link": "https:\/\/blog.naver.com\/fintechkisa?Redirect=Log&logNo=222147375004",
# "description": "<b>신청방법</b> : 이메일(***********@*****.***) 접수 7. 시상규모 및 특전 : 15팀(총 상금 2,500만원... 카카오오픈채팅 : https://open.kakao.com/o/gYfKujFc (챌린지 해커톤 검색) ○ <b>네이버</b>밴드 : band.us/@nhhackathon",
# "bloggername": "한국인터넷진흥원 핀테크 기술지원센터",
# "bloggerlink": "https://blog.naver.com/fintechkisa",
# "postdate": "20201118"
#
# },
# {
# "title": "2020년 11월 18일 수요일 신문브리핑",
# "link": "https://lhw9910.tistory.com/entry/2020%EB%85%84-11%EC%9B%94-18%EC%9D%BC-%EC%88%98%EC%9A%94%EC%9D%BC-%EC%8B%A0%EB%AC%B8%EB%B8%8C%EB%A6%AC%ED%95%91",
# "description": "ai로 <b>신청</b>하시기 바랍니다. 랜딩 : http://moya.ai 모바일 App : http://app.moya.ai 대시보드 : https://watch.... 개발하는 <b>방법</b>론을 두 가지 응용서비스를 통해 공개했다. 인공지능 서비스인 ‘AI 패션... ",
# "bloggername": "블로그",
# "bloggerlink": "http://lhw9910.tistory.com/",
# "postdate": "20201118"
#
# },
# {
# "title": "나만의 키워드 발굴, 상품 발굴, <b>네이버</b> 광고 키워드 도구... ",
# "link": "https:\/\/blog.naver.com\/o12486vs2?Redirect=Log&logNo=222146186928",
# "description": "수집하는 <b>방법</b>을 알아 보았습니다. 수집은 했으나, 어떻게 써먹어야 할지 알고... <b>네이버</b> 광고 <b>API 신청</b> 우선 <b>API 신청</b>이 필요 합니다. 자료 요청을 하기 위한 key값 비밀번호 등을... ",
# "bloggername": "으뜸이네",
# "bloggerlink": "https://blog.naver.com/o12486vs2",
# "postdate": "20201117"
#
# },
# {
# "title": "[이렇게 사용하세요!] NAVER Clova OCR과 NAVER Clova CSS로... ",
# "link": "https:\/\/blog.naver.com\/n_cloudplatform?Redirect=Log&logNo=222145332633",
# "description": "CSS <b>API</b> Request Header CSS 서비스 <b>신청</b> 및 등록 CSS 약관 확인 및 이용<b>신청</b> <b>네이버</b>... 이렇게 1, 2편을 통해 OCR과 TTS로 비대면 서비스를 구성하는 <b>방법</b>에 대해 배워봤는데요!... ",
# "bloggername": "네이버 클라우드 플랫폼 (NAVER CLOUD PLATFORM)",
# "bloggerlink": "https://blog.naver.com/n_cloudplatform",
# "postdate": "20201116"
#
# },
# {
# "title": "[이렇게 사용하세요!] NAVER Clova OCR과 NAVER Clova CSS로... ",
# "link": "https:\/\/blog.naver.com\/n_cloudplatform?Redirect=Log&logNo=222145332269",
# "description": "주요 <b>API</b> 소개 <b>네이버</b> 클라우드 플랫폼의 OCR 서비스 상세한 사용<b>방법</b>은 &lt;그림7&gt;의 설명서를... html &lt;그림10&gt; <b>네이버</b> 클라우드 플랫폼 <b>API</b> 게이트웨이 아키텍처 OCR 서비스 <b>신청</b> 및 등록 1. OCR 약관... ",
# "bloggername": "네이버 클라우드 플랫폼 (NAVER CLOUD PLATFORM)",
# "bloggerlink": "https://blog.naver.com/n_cloudplatform",
# "postdate": "20201116"
#
# },
# {
# "title": "나를 나타내는 블로그 로얄 키워드 마스터",
# "link": "https:\/\/blog.naver.com\/keyword190?Redirect=Log&logNo=222144791948",
# "description": "로얄키워드 툴이 있는 분들은 로얄키워드 마스터 <b>방법</b>이 쉽게 마스터 할 수 있지만 로얄키워드 툴이... 바로 그곳에서 제공해주는 월간검색수를 <b>API</b> 이용하여 빠르게 가져오고 <b>네이버</b> 검색 VIEW 상황에 맞춰서... ",
# "bloggername": "키워드 마스터 짱박 *(^_^)*",
# "bloggerlink": "https://blog.naver.com/keyword190",
# "postdate": "20201115"
#
# },
# {
# "title": "와디즈펀딩 / [글로벌 17억 펀딩] 전 세계가 반한 SwitchBot... ",
# "link": "https:\/\/blog.naver.com\/iamcjs4?Redirect=Log&logNo=222144299035",
# "description": "평범한 커튼을 손쉽게 스타일리쉬한 전동커튼으로 바꿀 수 있습니다:) 프로젝트 스토리 알림<b>신청</b>... * 추후 <b>네이버</b> 클로바(Naver Clova)도 추가 예정입니다. 06. 스위치봇 제품과의 연동으로 다양한... ",
# "bloggername": "NEXT",
# "bloggerlink": "https://blog.naver.com/iamcjs4",
# "postdate": "20201114"
#
# }
# ]
# }

# %%
#write your code (100문이 일여불타)

# %% [markdown]
# 4. 해당 키워드의 포스팅일자와 총 발행량을 체크한다.

# %%
response_dict.keys()
# 총 발행량 확인
posting_total = 100
print(posting_total)
# 마지막 포스팅 생성날짜 확인
last_posting = response_dict["items"][-1]
last_posting["postdate"]
# 오늘 날짜 확인
import datetime
today = datetime.datetime.today()
print(today)
# 마지막 포스팅 생성날짜 datetime 변환
last_year = int(last_posting["postdate"][:4])
last_month = int(last_posting["postdate"][4:6])
last_day = int(last_posting["postdate"][6:])
last_day = datetime.datetime(last_year,last_month,last_day)
print(last_day)
#마지막 포스팅일자 - 오늘 날짜 계산
date_difference = today - last_day
date_difference.days
# Out:
# 100
# 2021-01-22 07:31:32.206088
# 2020-11-14 00:00:00
# 69

# %%
#write your code (100문이 일여불타)

# %% [markdown]
# 5. 오늘 글을 올렸을 때의 경쟁률을 알아본다.

# %%
#하루평균 발행량 확인
posting_total/date_difference.days
# Out:
# 1.4492753623188406

# %%
#write your code (100문이 일여불타)

# %% [markdown]
# 6. 원코드로 만든다.

# %%
#write your code (100문이 일여불타)
