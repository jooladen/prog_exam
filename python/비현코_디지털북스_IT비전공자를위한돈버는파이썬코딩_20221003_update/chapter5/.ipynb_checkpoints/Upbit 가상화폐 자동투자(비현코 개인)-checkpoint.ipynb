# %% [markdown]
# # 상황설정
# - 2021.5.11 강의 노트 업데이트
# - 암호화페열풍의 중심 Upbit 의 Open API를 통해 자동투자의 기본을 배우고, 설정한 가설에 의한 자동 투자푸로그램을 제작
#
# ### 프로그램의 목적:
# - 암호화폐 거래의 특징은 24시간 지속된다는 것에 있습니다.
# - 매시간 매분 가격을 체크하고 투자를 하고 있다면, 일상생활에 지장을 줄 정도로 피곤해지는게 암호화폐 투자의 단점입니다.
# - 단순한 코인별 가격조회, 지정가 매수, 시장가 매수 , 지정가 매도, 시장가 매도 등 기본을 배웁니다.
# - 이후 가설을 하나 세워 자동투자를 진행합니다.
#
# ### 쿠팡파트너스 API 활용방법 순서
# 1. 업비트 API를 발급받는다.
# 2. 암호화폐 시세/과거거래기록
# 3. 암호화폐 내 잔고의 잔액조회
# 4. 암호화폐 매수/매도
# 4. 투자아이디어 설정
# 5. 투자 아이디어 프로그램 제작
#
#
# * 투자관련경고 - 해당 프로그램은 학습을 위해 만든 하나의 '가설' 입니다. 해당 시스템으로 투자를 했을 경우 피해/손실이 발생할 수 있습니다.
#
# # 모든 투자는 개인의 책임하에 진행해야 합니다.
#
# * 주의 - 모든 코딩과정을 이해하고 따라오기에는 매우 오랜 시간이 걸립니다.
# 그런 오랜 시간을 견디지 못하고 많은 비전공자분들이 코딩의 문턱을 넘지 못합니다.
# 각자의 학습스타일에 따라 다르겠지만,
# 이해하기보다는 "아~ 이렇게 쓰는구나!" 라고 생각하고 학습에 임해주세요.
# 마치, 우리가 엑셀의 vlookup,if등의 함수를 쓸 때,
# 하나하나 제작된 원리를 이해해서 하기보다는 자주 쓰다보니 외어지는 것 처럼 말이죠!
#
# (제가 경험했던 가장 큰 실수는 모든 것을 이해하고 다음으로 넘어가려했기 때문입니다. 일단 기능에만 충실해주세요)
#
# (그리고 그러다보면 어느순간 내가 만들고 싶은 프로그램을 만들고 계실 것입니다.)

# %% [markdown]
# ### 1. 업비트 API 발급받기

# %%
#업비트 가입 및 접속  www.upbit.com
# (로그인상태에서)가입 후 4단계 보안인증 진행 https://upbit.com/mypage/security_certificate
# (로그인상태에서)OPEN API 발급방법  https://upbit.com/mypage/open_api_management

# %% [markdown]
# ### 2. 암호화폐 시세/과거거래기록

# %%
#거래소 구조 설명 https://docs.upbit.com/docs

# - 원화거래 / BTC 거래 / USDT 거래
#암호화폐 종류체크 및 종류 입력_방법은 알려드리지만, 그냥 활용하세요.

#1.업비트의 코인 종류 체크

import requests
import json

def coins(current):
    url = "https://api.upbit.com/v1/market/all"
    querystring = {"isDetails":"true"}
    response = requests.request("GET", url, params=querystring)
    response_json = json.loads(response.text)

    KRWticker = []
    BTCticker = []
    USDTticker = []

    for a in response_json:
    #     print(a['market'])
        if "KRW-" in a['market']:
            KRWticker.append(a['market'])
        elif "BTC-" in a['market']:
            BTCticker.append(a['market'])
        elif "USDT-" in a['market']:
            USDTticker.append(a['market'])    
    ticker = {
        "KRW":KRWticker,
        "BTC":BTCticker,
        "USDT":USDTticker
    }
#     print(ticker)
    if current=="ALL":
        ticker = ticker
    else:
        ticker = ticker[current]
    return ticker

# %%
coins("ALL")
# Out:
# {'KRW': ['KRW-BTC',
#   'KRW-ETH',
#   'KRW-NEO',
#   'KRW-MTL',
#   'KRW-LTC',
#   'KRW-XRP',
#   'KRW-ETC',
#   'KRW-OMG',
#   'KRW-SNT',
#   'KRW-WAVES',
#   'KRW-XEM',
#   'KRW-QTUM',
#   'KRW-LSK',
#   'KRW-STEEM',
#   'KRW-XLM',
#   'KRW-ARDR',
#   'KRW-KMD',
#   'KRW-ARK',
#   'KRW-STORJ',
#   'KRW-GRS',
#   'KRW-REP',
#   'KRW-EMC2',
#   'KRW-ADA',
#   'KRW-SBD',
#   'KRW-POWR',
#   'KRW-BTG',
#   'KRW-ICX',
#   'KRW-EOS',
#   'KRW-TRX',
#   'KRW-SC',
#   'KRW-IGNIS',
#   'KRW-ONT',
#   'KRW-ZIL',
#   'KRW-POLY',
#   'KRW-ZRX',
#   'KRW-LOOM',
#   'KRW-BCH',
#   'KRW-ADX',
#   'KRW-BAT',
#   'KRW-IOST',
#   'KRW-DMT',
#   'KRW-RFR',
#   'KRW-CVC',
#   'KRW-IQ',
#   'KRW-IOTA',
#   'KRW-MFT',
#   'KRW-ONG',
#   'KRW-GAS',
#   'KRW-UPP',
#   'KRW-ELF',
#   'KRW-KNC',
#   'KRW-BSV',
#   'KRW-THETA',
#   'KRW-EDR',
#   'KRW-QKC',
#   'KRW-BTT',
#   'KRW-MOC',
#   'KRW-ENJ',
#   'KRW-TFUEL',
#   'KRW-MANA',
#   'KRW-ANKR',
#   'KRW-AERGO',
#   'KRW-ATOM',
#   'KRW-TT',
#   'KRW-CRE',
#   'KRW-SOLVE',
#   'KRW-MBL',
#   'KRW-TSHP',
#   'KRW-WAXP',
#   'KRW-HBAR',
#   'KRW-MED',
#   'KRW-MLK',
#   'KRW-STPT',
#   'KRW-ORBS',
#   'KRW-VET',
#   'KRW-CHZ',
#   'KRW-PXL',
#   'KRW-STMX',
#   'KRW-DKA',
#   'KRW-HIVE',
#   'KRW-KAVA',
#   'KRW-AHT',
#   'KRW-LINK',
#   'KRW-XTZ',
#   'KRW-BORA',
#   'KRW-JST',
#   'KRW-CRO',
#   'KRW-TON',
#   'KRW-SXP',
#   'KRW-LAMB',
#   'KRW-HUNT',
#   'KRW-MARO',
#   'KRW-PLA',
#   'KRW-DOT',
#   'KRW-SRM',
#   'KRW-MVL',
#   'KRW-PCI',
#   'KRW-STRAX',
#   'KRW-AQT',
#   'KRW-BCHA',
#   'KRW-GLM',
#   'KRW-QTCON',
#   'KRW-SSX',
#   'KRW-META',
#   'KRW-OBSR',
#   'KRW-FCT2',
#   'KRW-LBC',
#   'KRW-CBK',
#   'KRW-SAND',
#   'KRW-HUM',
#   'KRW-DOGE',
#   'KRW-STRK',
#   'KRW-PUNDIX',
#   'KRW-FLOW',
#   'KRW-DAWN',
#   'KRW-AXS',
#   'KRW-STX'],
#  'BTC': ['BTC-ETH',
#   'BTC-LTC',
#   'BTC-XRP',
#   'BTC-ETC',
#   'BTC-OMG',
#   'BTC-CVC',
#   'BTC-DGB',
#   'BTC-SC',
#   'BTC-SNT',
#   'BTC-WAVES',
#   'BTC-NMR',
#   'BTC-XEM',
#   'BTC-LBC',
#   'BTC-QTUM',
#   'BTC-NXT',
#   'BTC-BAT',
#   'BTC-LSK',
#   'BTC-RDD',
#   'BTC-STEEM',
#   'BTC-DOGE',
#   'BTC-BNT',
#   'BTC-XLM',
#   'BTC-ARDR',
#   'BTC-KMD',
#   'BTC-ARK',
#   'BTC-ADX',
#   'BTC-SYS',
#   'BTC-ANT',
#   'BTC-STORJ',
#   'BTC-GRS',
#   'BTC-REP',
#   'BTC-RLC',
#   'BTC-EMC2',
#   'BTC-ADA',
#   'BTC-MANA',
#   'BTC-SBD',
#   'BTC-RCN',
#   'BTC-POWR',
#   'BTC-DNT',
#   'BTC-IGNIS',
#   'BTC-ZRX',
#   'BTC-TRX',
#   'BTC-TUSD',
#   'BTC-LRC',
#   'BTC-DMT',
#   'BTC-POLY',
#   'BTC-PRO',
#   'BTC-BCH',
#   'BTC-MFT',
#   'BTC-LOOM',
#   'BTC-RFR',
#   'BTC-RVN',
#   'BTC-BFT',
#   'BTC-GO',
#   'BTC-UPP',
#   'BTC-ENJ',
#   'BTC-EDR',
#   'BTC-MTL',
#   'BTC-PAX',
#   'BTC-MOC',
#   'BTC-ZIL',
#   'BTC-BSV',
#   'BTC-IOST',
#   'BTC-NCASH',
#   'BTC-DENT',
#   'BTC-ELF',
#   'BTC-BTT',
#   'BTC-VITE',
#   'BTC-IOTX',
#   'BTC-SOLVE',
#   'BTC-NKN',
#   'BTC-META',
#   'BTC-ANKR',
#   'BTC-CRO',
#   'BTC-FSN',
#   'BTC-ORBS',
#   'BTC-AERGO',
#   'BTC-PI',
#   'BTC-ATOM',
#   'BTC-STPT',
#   'BTC-LAMB',
#   'BTC-EOS',
#   'BTC-LUNA',
#   'BTC-DAI',
#   'BTC-MKR',
#   'BTC-BORA',
#   'BTC-TSHP',
#   'BTC-WAXP',
#   'BTC-MED',
#   'BTC-MLK',
#   'BTC-PXL',
#   'BTC-VET',
#   'BTC-CHZ',
#   'BTC-FX',
#   'BTC-OGN',
#   'BTC-ITAM',
#   'BTC-XTZ',
#   'BTC-HIVE',
#   'BTC-HBD',
#   'BTC-OBSR',
#   'BTC-DKA',
#   'BTC-STMX',
#   'BTC-AHT',
#   'BTC-PCI',
#   'BTC-RINGX',
#   'BTC-LINK',
#   'BTC-KAVA',
#   'BTC-JST',
#   'BTC-CHR',
#   'BTC-DAD',
#   'BTC-TON',
#   'BTC-CTSI',
#   'BTC-DOT',
#   'BTC-COMP',
#   'BTC-SXP',
#   'BTC-HUNT',
#   'BTC-ONIT',
#   'BTC-CRV',
#   'BTC-ALGO',
#   'BTC-RSR',
#   'BTC-OXT',
#   'BTC-PLA',
#   'BTC-MARO',
#   'BTC-SAND',
#   'BTC-SUN',
#   'BTC-SRM',
#   'BTC-QTCON',
#   'BTC-MVL',
#   'BTC-GXC',
#   'BTC-AQT',
#   'BTC-AXS',
#   'BTC-STRAX',
#   'BTC-BCHA',
#   'BTC-GLM',
#   'BTC-FCT2',
#   'BTC-SSX',
#   'BTC-FIL',
#   'BTC-UNI',
#   'BTC-BASIC',
#   'BTC-INJ',
#   'BTC-PROM',
#   'BTC-VAL',
#   'BTC-PSG',
#   'BTC-JUV',
#   'BTC-CBK',
#   'BTC-FOR',
#   'BTC-BFC',
#   'BTC-LINA',
#   'BTC-HUM',
#   'BTC-PICA',
#   'BTC-CELO',
#   'BTC-IQ',
#   'BTC-STX',
#   'BTC-NEAR',
#   'BTC-AUCTION',
#   'BTC-DAWN',
#   'BTC-FLOW',
#   'BTC-STRK',
#   'BTC-PUNDIX',
#   'BTC-GRT',
#   'BTC-SNX'],
#  'USDT': ['USDT-BTC',
#   'USDT-ETH',
#   'USDT-LTC',
#   'USDT-XRP',
#   'USDT-ETC',
#   'USDT-OMG',
#   'USDT-ADA',
#   'USDT-TUSD',
#   'USDT-SC',
#   'USDT-TRX',
#   'USDT-BCH',
#   'USDT-DGB',
#   'USDT-DOGE',
#   'USDT-ZRX',
#   'USDT-RVN',
#   'USDT-BAT']}

# %%
#암호화폐 시세조회
import requests
import time

def coin_price(coin):
    url = "https://api.upbit.com/v1/orderbook"
    querystring = {"markets":coin}
    response = requests.request("GET", url, params=querystring)
    response_json = json.loads(response.text)
    coin_now_price = response_json[0]["orderbook_units"][0]["ask_price"]
    return coin_now_price

# %%
#시세 호가 정보(Orderbook) 조회 // 호가 정보 조회

import requests
import pandas as pd

def coin_history(coin,time1='minute',time2=""):
    url = f"https://api.upbit.com/v1/candles/{time1}/{time2}"

    querystring = {"market":coin,"count":"200"}

    response = requests.request("GET", url, params=querystring)
    response_json = json.loads(response.text)
    # print(type(response_json))
    df = pd.DataFrame(response_json)
    return df

# %%
coin_history("KRW-BTC","minutes",30)
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2021-05-16T07:00:00  2021-05-16T16:00:00     59822000.0
# 1    KRW-BTC  2021-05-16T06:30:00  2021-05-16T15:30:00     59983000.0
# 2    KRW-BTC  2021-05-16T06:00:00  2021-05-16T15:00:00     59058000.0
# 3    KRW-BTC  2021-05-16T05:30:00  2021-05-16T14:30:00     59000000.0
# 4    KRW-BTC  2021-05-16T05:00:00  2021-05-16T14:00:00     58851000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-BTC  2021-05-12T05:30:00  2021-05-12T14:30:00     70054000.0
# 196  KRW-BTC  2021-05-12T05:00:00  2021-05-12T14:00:00     70168000.0
# 197  KRW-BTC  2021-05-12T04:30:00  2021-05-12T13:30:00     70280000.0
# 198  KRW-BTC  2021-05-12T04:00:00  2021-05-12T13:00:00     70170000.0
# 199  KRW-BTC  2021-05-12T03:30:00  2021-05-12T12:30:00     69594000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    59853000.0  59674000.0   59736000.0  1621149279945
# 1    60140000.0  59529000.0   59822000.0  1621148400057
# 2    60350000.0  59043000.0   59987000.0  1621146600537
# 3    59200000.0  58957000.0   59059000.0  1621144800209
# 4    59050000.0  58847000.0   59000000.0  1621142999929
# ..          ...         ...          ...            ...
# 195  70055000.0  69769000.0   69804000.0  1620799199327
# 196  70200000.0  70001000.0   70052000.0  1620797399372
# 197  70280000.0  70003000.0   70140000.0  1620795599792
# 198  70499000.0  70169000.0   70279000.0  1620793800659
# 199  70440000.0  69574000.0   70144000.0  1620792000232
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              6.652499e+09               111.361578    30
# 1              1.950673e+10               325.769553    30
# 2              3.436916e+10               574.127093    30
# 3              9.343402e+09               158.215625    30
# 4              1.003368e+10               170.199779    30
# ..                      ...                      ...   ...
# 195            9.220774e+09               131.952410    30
# 196            6.186072e+09                88.235610    30
# 197            8.461579e+09               120.653851    30
# 198            1.248937e+10               177.503054    30
# 199            2.243426e+10               319.895244    30
#
# [200 rows x 11 columns]

# %% [markdown]
# ### 3. 암호화폐 내 잔고의 잔액조회

# %%
#로그인
def login():
    f=open("upbit_api_key.txt")
    lines = f.readlines()
    global access_key
    global secret_key
    access_key = str(lines[0].strip())
    secret_key = str(lines[1].strip())
    f.close

# %%
login()

# %%
#나의 계좌 잔액 조회
import os
import jwt
import uuid
import hashlib
from urllib.parse import urlencode

import requests

def balance():
    global server_url
    server_url = 'https://api.upbit.com'

    payload = {
        'access_key': access_key,
        'nonce': str(uuid.uuid4()),
    }

    jwt_token = jwt.encode(payload, secret_key)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.get(server_url + "/v1/accounts", headers=headers)
    print(res.json())
    return res.json()

# %%
balance()
# Out:
# [{'currency': 'KRW',
#   'balance': '989967.11752283',
#   'locked': '0.0',
#   'avg_buy_price': '0',
#   'avg_buy_price_modified': True,
#   'unit_currency': 'KRW'},
#  {'currency': 'XRP',
#   'balance': '5.24934383',
#   'locked': '0.0',
#   'avg_buy_price': '1907.44',
#   'avg_buy_price_modified': False,
#   'unit_currency': 'KRW'}]

# %% [markdown]
# ### 4. 암호화폐 매수/매도

# %%
#매수(지정가)
import os
import jwt
import uuid
import hashlib
from urllib.parse import urlencode

import requests

# access_key = os.environ['UPBIT_OPEN_API_ACCESS_KEY']
# secret_key = os.environ['UPBIT_OPEN_API_SECRET_KEY']
# server_url = os.environ['UPBIT_OPEN_API_SERVER_URL']

def buy_limit(coin,volume,price):
    query = {
        'market': coin,
        'side': 'bid',
        'volume': volume,
        'price': price,
        'ord_type': 'limit',
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': access_key,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, secret_key)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.post(server_url + "/v1/orders", params=query, headers=headers)
    print(res.json())
    return res.json()

# %%
buy_limit("KRW-XRP",5,1950)
# Out:
# {'uuid': '0b07bdfa-a203-443e-8a55-f80bb996da51', 'side': 'bid', 'ord_type': 'limit', 'price': '1950.0', 'state': 'wait', 'market': 'KRW-XRP', 'created_at': '2021-05-16T14:12:03+09:00', 'volume': '5.0', 'remaining_volume': '5.0', 'reserved_fee': '4.875', 'remaining_fee': '4.875', 'paid_fee': '0.0', 'locked': '9754.875', 'executed_volume': '0.0', 'trades_count': 0}

# %%
#매수(시장가)
import os
import jwt
import uuid
import hashlib
from urllib.parse import urlencode

import requests

# access_key = os.environ['UPBIT_OPEN_API_ACCESS_KEY']
# secret_key = os.environ['UPBIT_OPEN_API_SECRET_KEY']
# server_url = os.environ['UPBIT_OPEN_API_SERVER_URL']

def buy_market(coin,price):
    query = {
        'market': coin,
        'side': 'bid',
        'volume': '',
        'price': price,
        'ord_type': 'price',
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': access_key,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, secret_key)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.post(server_url + "/v1/orders", params=query, headers=headers)
    print(res.json())
    return res.json()

# %%
#시장가구매
buy_market("KRW-XRP",10000)
# Out:
# {'uuid': '065f7f72-9956-4521-8feb-b51e27220c51', 'side': 'bid', 'ord_type': 'price', 'price': '10000.0', 'state': 'wait', 'market': 'KRW-XRP', 'created_at': '2021-05-16T14:14:07+09:00', 'volume': None, 'remaining_volume': None, 'reserved_fee': '5.0', 'remaining_fee': '5.0', 'paid_fee': '0.0', 'locked': '10005.0', 'executed_volume': '0.0', 'trades_count': 0}

# %%
#매도(지정가)

import os
import jwt
import uuid
import hashlib
from urllib.parse import urlencode

import requests

# access_key = os.environ['UPBIT_OPEN_API_ACCESS_KEY']
# secret_key = os.environ['UPBIT_OPEN_API_SECRET_KEY']
# server_url = os.environ['UPBIT_OPEN_API_SERVER_URL']

def sell_limit(coin,volume,price):
    query = {
        'market': coin,
        'side': 'ask',
        'volume': volume,
        'price': price,
        'ord_type': 'limit',
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': access_key,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, secret_key)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.post(server_url + "/v1/orders", params=query, headers=headers)
    print(res.json())
    return res.json()

# %%
#시장가판매
sell_limit("KRW-XRP",5,1900)
# Out:
# {'uuid': '4fa50464-06bd-4618-81e2-13ead2499b17', 'side': 'ask', 'ord_type': 'limit', 'price': '1900.0', 'state': 'wait', 'market': 'KRW-XRP', 'created_at': '2021-05-16T14:16:04+09:00', 'volume': '5.0', 'remaining_volume': '5.0', 'reserved_fee': '0.0', 'remaining_fee': '0.0', 'paid_fee': '0.0', 'locked': '5.0', 'executed_volume': '0.0', 'trades_count': 0}

# %%
#지정가판매
sell_limit()

# %%
#매도(시장가)


import os
import jwt
import uuid
import hashlib
from urllib.parse import urlencode

import requests

# access_key = os.environ['UPBIT_OPEN_API_ACCESS_KEY']
# secret_key = os.environ['UPBIT_OPEN_API_SECRET_KEY']
# server_url = os.environ['UPBIT_OPEN_API_SERVER_URL']

def sell_market(coin,volume):
    query = {
        'market': coin,
        'side': 'ask',
        'volume': volume,
        'price': '',
        'ord_type': 'market',
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': access_key,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, secret_key)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.post(server_url + "/v1/orders", params=query, headers=headers)
    print(res.json())
    return res.json()

# %%
sell_market("KRW-XRP",5.24934383)
# Out:
# {'uuid': 'f922a4d3-68f7-4bfe-82b8-8380e10e7d33', 'side': 'ask', 'ord_type': 'market', 'price': None, 'state': 'wait', 'market': 'KRW-XRP', 'created_at': '2021-05-16T14:23:22+09:00', 'volume': '5.24934383', 'remaining_volume': '5.24934383', 'reserved_fee': '0.0', 'remaining_fee': '0.0', 'paid_fee': '0.0', 'locked': '5.24934383', 'executed_volume': '0.0', 'trades_count': 0}

# %% [markdown]
# ##  사용하기 편하게 함수로 제작 ( !pip install bhyunco_upbit)
#
#
#
# ## 구매가능한 코인 확인
#
# coins("KRW") #한화코인확인
#
# coins("BTC") #BTC코인확인
#
# coins("USDT") #USDT코인확인
#
# coins("ALL") #전체코인확인
#
#
# ## 현재 코인 호가
# coin_price("KRW-BTC")
#
# ## 코인 거래내역
# coin_history(코인이름,시간기준1,시간기준2)
# 시간기준1 = 기본은 "minutes"
#
# ## 로그인
# login() #파이썬 파일이 있는 폴더에 "upbit_api_key.txt" 를 저장하고 첫번쨰줄에는 ID / 밑에줄에는 패스워드를 넣는다.
#
# ## 내계좌잔액조회
# balance() #로그인 한후 활용가능
#
# ## 지정가구매
# buy_limit(코인이름,갯수,가격)
#
# ## 시장가구매
# buy_market(코인이름,구매액수) #로그인 한후 활용가능
#
# ## 지정가판매
# sell_limit(코인이름,갯수,가격)
#
# ## 시장가판매
# sell_market(코인이름,갯수)

# %% [markdown]
# ### 5. 투자아이디어 설정

# %%
#1분봉으로 200분 안에 제일 하락을 많이 한 코인을 찾기
# coin_history("KRW-BTC","minutes",30)
tickers = coins("KRW")
decrease_top_score =0.001
# ticker = "KRW-BTC"
for ticker in tickers:
    coin_1_m = coin_history(ticker,'minutes',1)
    print(coin_1_m)

    max_high_price = coin_1_m["high_price"].max()
    now_price = coin_price(ticker)
#     print(ticker)
#     print(max_high_price)
#     print(now_price)
#     print("하락률 : " + str(round(((1-(now_price/max_high_price))*100),3)) + "%")
    decrease_percent = round(((1-(now_price/max_high_price))*100),3)
    if decrease_percent > decrease_top_score :
        decrease_top_score = decrease_percent
        decrease_top_score_ticker = [ticker,max_high_price,now_price,(-1)*decrease_percent]


print(decrease_top_score_ticker)
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2021-05-16T07:16:00  2021-05-16T16:16:00     59765000.0
# 1    KRW-BTC  2021-05-16T07:15:00  2021-05-16T16:15:00     59730000.0
# 2    KRW-BTC  2021-05-16T07:14:00  2021-05-16T16:14:00     59738000.0
# 3    KRW-BTC  2021-05-16T07:13:00  2021-05-16T16:13:00     59745000.0
# 4    KRW-BTC  2021-05-16T07:12:00  2021-05-16T16:12:00     59728000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-BTC  2021-05-16T04:01:00  2021-05-16T13:01:00     58973000.0
# 196  KRW-BTC  2021-05-16T04:00:00  2021-05-16T13:00:00     58900000.0
# 197  KRW-BTC  2021-05-16T03:59:00  2021-05-16T12:59:00     58733000.0
# 198  KRW-BTC  2021-05-16T03:58:00  2021-05-16T12:58:00     58704000.0
# 199  KRW-BTC  2021-05-16T03:57:00  2021-05-16T12:57:00     58700000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    59800000.0  59744000.0   59790000.0  1621149396286
# 1    59762000.0  59727000.0   59762000.0  1621149360120
# 2    59743000.0  59730000.0   59730000.0  1621149300346
# 3    59745000.0  59730000.0   59738000.0  1621149240224
# 4    59765000.0  59728000.0   59745000.0  1621149179753
# ..          ...         ...          ...            ...
# 195  59084000.0  58967000.0   59032000.0  1621137719721
# 196  58999000.0  58823000.0   58996000.0  1621137660469
# 197  58900000.0  58731000.0   58820000.0  1621137599934
# 198  58750000.0  58700000.0   58735000.0  1621137540284
# 199  58710000.0  58698000.0   58704000.0  1621137479801
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.756267e+08                 2.938231     1
# 1              5.552539e+08                 9.294779     1
# 2              4.500609e+08                 7.534160     1
# 3              2.916303e+08                 4.881673     1
# 4              5.164253e+08                 8.643466     1
# ..                      ...                      ...   ...
# 195            1.157263e+09                19.616635     1
# 196            9.649946e+08                16.377150     1
# 197            5.376660e+08                 9.144010     1
# 198            3.213760e+08                 5.473666     1
# 199            3.513513e+08                 5.985465     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-ETH  2021-05-16T07:16:00  2021-05-16T16:16:00      4696000.0
# 1    KRW-ETH  2021-05-16T07:15:00  2021-05-16T16:15:00      4691000.0
# 2    KRW-ETH  2021-05-16T07:14:00  2021-05-16T16:14:00      4693000.0
# 3    KRW-ETH  2021-05-16T07:13:00  2021-05-16T16:13:00      4694000.0
# 4    KRW-ETH  2021-05-16T07:12:00  2021-05-16T16:12:00      4697000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-ETH  2021-05-16T04:01:00  2021-05-16T13:01:00      4658000.0
# 196  KRW-ETH  2021-05-16T04:00:00  2021-05-16T13:00:00      4654000.0
# 197  KRW-ETH  2021-05-16T03:59:00  2021-05-16T12:59:00      4652000.0
# 198  KRW-ETH  2021-05-16T03:58:00  2021-05-16T12:58:00      4646000.0
# 199  KRW-ETH  2021-05-16T03:57:00  2021-05-16T12:57:00      4653000.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0     4699000.0  4696000.0    4698000.0  1621149397381
# 1     4699000.0  4691000.0    4696000.0  1621149359289
# 2     4695000.0  4691000.0    4692000.0  1621149299915
# 3     4696000.0  4693000.0    4693000.0  1621149240809
# 4     4697000.0  4694000.0    4695000.0  1621149179933
# ..          ...        ...          ...            ...
# 195   4662000.0  4656000.0    4661000.0  1621137719970
# 196   4659000.0  4653000.0    4658000.0  1621137660266
# 197   4655000.0  4650000.0    4655000.0  1621137599722
# 198   4654000.0  4645000.0    4653000.0  1621137539720
# 199   4653000.0  4644000.0    4646000.0  1621137479368
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              7.132542e+07                15.185637     1
# 1              3.587750e+08                76.427254     1
# 2              2.544158e+08                54.220713     1
# 3              2.716773e+08                57.871416     1
# 4              2.288870e+08                48.755125     1
# ..                      ...                      ...   ...
# 195            5.441461e+08               116.799827     1
# 196            5.218301e+08               112.060887     1
# 197            3.231285e+08                69.443738     1
# 198            3.391124e+08                72.927184     1
# 199            4.139706e+08                89.080538     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-NEO  2021-05-16T07:16:00  2021-05-16T16:16:00       119500.0
# 1    KRW-NEO  2021-05-16T07:15:00  2021-05-16T16:15:00       119650.0
# 2    KRW-NEO  2021-05-16T07:14:00  2021-05-16T16:14:00       119650.0
# 3    KRW-NEO  2021-05-16T07:13:00  2021-05-16T16:13:00       119800.0
# 4    KRW-NEO  2021-05-16T07:12:00  2021-05-16T16:12:00       119600.0
# ..       ...                  ...                  ...            ...
# 195  KRW-NEO  2021-05-16T04:01:00  2021-05-16T13:01:00       116650.0
# 196  KRW-NEO  2021-05-16T04:00:00  2021-05-16T13:00:00       116400.0
# 197  KRW-NEO  2021-05-16T03:59:00  2021-05-16T12:59:00       116250.0
# 198  KRW-NEO  2021-05-16T03:58:00  2021-05-16T12:58:00       116200.0
# 199  KRW-NEO  2021-05-16T03:57:00  2021-05-16T12:57:00       116200.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0      119600.0   119450.0     119600.0  1621149397494
# 1      119650.0   119350.0     119450.0  1621149359334
# 2      119750.0   119650.0     119650.0  1621149299009
# 3      119850.0   119650.0     119650.0  1621149237573
# 4      119850.0   119600.0     119800.0  1621149175715
# ..          ...        ...          ...            ...
# 195    116700.0   116550.0     116700.0  1621137716247
# 196    116650.0   116350.0     116650.0  1621137659556
# 197    116400.0   116150.0     116400.0  1621137599140
# 198    116250.0   116150.0     116250.0  1621137537115
# 199    116200.0   116150.0     116200.0  1621137475508
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              3.060518e+07               256.085859     1
# 1              3.195618e+07               267.280141     1
# 2              8.253156e+07               689.739106     1
# 3              5.833622e+07               486.921929     1
# 4              2.765856e+07               230.981255     1
# ..                      ...                      ...   ...
# 195            1.017558e+08               872.595380     1
# 196            4.774160e+07               409.707698     1
# 197            5.574025e+07               479.495012     1
# 198            3.839871e+07               330.452860     1
# 199            1.477219e+07               127.136433     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-MTL  2021-05-16T07:16:00  2021-05-16T16:16:00         4015.0
# 1    KRW-MTL  2021-05-16T07:15:00  2021-05-16T16:15:00         4010.0
# 2    KRW-MTL  2021-05-16T07:14:00  2021-05-16T16:14:00         4005.0
# 3    KRW-MTL  2021-05-16T07:13:00  2021-05-16T16:13:00         4010.0
# 4    KRW-MTL  2021-05-16T07:12:00  2021-05-16T16:12:00         4010.0
# ..       ...                  ...                  ...            ...
# 195  KRW-MTL  2021-05-16T03:57:00  2021-05-16T12:57:00         3975.0
# 196  KRW-MTL  2021-05-16T03:56:00  2021-05-16T12:56:00         3975.0
# 197  KRW-MTL  2021-05-16T03:55:00  2021-05-16T12:55:00         3955.0
# 198  KRW-MTL  2021-05-16T03:54:00  2021-05-16T12:54:00         3955.0
# 199  KRW-MTL  2021-05-16T03:53:00  2021-05-16T12:53:00         3955.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        4015.0     4015.0       4015.0  1621149386687
# 1        4015.0     4010.0       4015.0  1621149339728
# 2        4015.0     4005.0       4015.0  1621149274252
# 3        4010.0     4010.0       4010.0  1621149236820
# 4        4010.0     4010.0       4010.0  1621149171552
# ..          ...        ...          ...            ...
# 195      3975.0     3970.0       3975.0  1621137477852
# 196      3975.0     3975.0       3975.0  1621137400350
# 197      3970.0     3955.0       3970.0  1621137357104
# 198      3955.0     3955.0       3955.0  1621137285912
# 199      3955.0     3950.0       3950.0  1621137233948
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.102922e+06               274.700259     1
# 1              6.326807e+05               157.658356     1
# 2              3.518093e+06               877.944383     1
# 3              8.289190e+06              2067.129764     1
# 4              1.203893e+06               300.222749     1
# ..                      ...                      ...   ...
# 195            1.570396e+07              3951.273944     1
# 196            2.905066e+07              7308.341949     1
# 197            3.044998e+06               767.641451     1
# 198            3.185050e+05                80.532248     1
# 199            2.559651e+06               647.337207     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-LTC  2021-05-16T07:16:00  2021-05-16T16:16:00       382800.0
# 1    KRW-LTC  2021-05-16T07:15:00  2021-05-16T16:15:00       382750.0
# 2    KRW-LTC  2021-05-16T07:14:00  2021-05-16T16:14:00       382750.0
# 3    KRW-LTC  2021-05-16T07:13:00  2021-05-16T16:13:00       382750.0
# 4    KRW-LTC  2021-05-16T07:12:00  2021-05-16T16:12:00       382750.0
# ..       ...                  ...                  ...            ...
# 195  KRW-LTC  2021-05-16T04:01:00  2021-05-16T13:01:00       380600.0
# 196  KRW-LTC  2021-05-16T04:00:00  2021-05-16T13:00:00       378650.0
# 197  KRW-LTC  2021-05-16T03:59:00  2021-05-16T12:59:00       378100.0
# 198  KRW-LTC  2021-05-16T03:58:00  2021-05-16T12:58:00       377750.0
# 199  KRW-LTC  2021-05-16T03:57:00  2021-05-16T12:57:00       378250.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0      383300.0   382800.0     383300.0  1621149394477
# 1      382800.0   382750.0     382800.0  1621149359584
# 2      382800.0   382700.0     382750.0  1621149294120
# 3      382800.0   382650.0     382800.0  1621149238527
# 4      382800.0   382700.0     382750.0  1621149179913
# ..          ...        ...          ...            ...
# 195    380600.0   380400.0     380600.0  1621137719899
# 196    380750.0   378650.0     380600.0  1621137658913
# 197    378900.0   378100.0     378900.0  1621137600082
# 198    378250.0   377600.0     378250.0  1621137538692
# 199    378350.0   377700.0     377700.0  1621137478685
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              5.598432e+07               146.177365     1
# 1              3.218108e+07                84.072162     1
# 2              1.483850e+07                38.767676     1
# 3              2.602293e+07                67.997595     1
# 4              1.723029e+07                45.016732     1
# ..                      ...                      ...   ...
# 195            9.211653e+07               242.130126     1
# 196            2.000303e+08               526.316188     1
# 197            2.529778e+07                66.867840     1
# 198            4.951161e+07               131.001340     1
# 199            3.213458e+07                84.979849     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-XRP  2021-05-16T07:16:00  2021-05-16T16:16:00         1915.0
# 1    KRW-XRP  2021-05-16T07:15:00  2021-05-16T16:15:00         1910.0
# 2    KRW-XRP  2021-05-16T07:14:00  2021-05-16T16:14:00         1910.0
# 3    KRW-XRP  2021-05-16T07:13:00  2021-05-16T16:13:00         1910.0
# 4    KRW-XRP  2021-05-16T07:12:00  2021-05-16T16:12:00         1910.0
# ..       ...                  ...                  ...            ...
# 195  KRW-XRP  2021-05-16T04:01:00  2021-05-16T13:01:00         1945.0
# 196  KRW-XRP  2021-05-16T04:00:00  2021-05-16T13:00:00         1945.0
# 197  KRW-XRP  2021-05-16T03:59:00  2021-05-16T12:59:00         1940.0
# 198  KRW-XRP  2021-05-16T03:58:00  2021-05-16T12:58:00         1940.0
# 199  KRW-XRP  2021-05-16T03:57:00  2021-05-16T12:57:00         1940.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        1920.0     1910.0       1915.0  1621149396382
# 1        1915.0     1910.0       1915.0  1621149360214
# 2        1915.0     1910.0       1910.0  1621149299319
# 3        1915.0     1910.0       1910.0  1621149240038
# 4        1915.0     1910.0       1915.0  1621149179260
# ..          ...        ...          ...            ...
# 195      1950.0     1935.0       1940.0  1621137720859
# 196      1955.0     1940.0       1945.0  1621137660214
# 197      1950.0     1935.0       1950.0  1621137602191
# 198      1945.0     1935.0       1940.0  1621137539897
# 199      1945.0     1935.0       1935.0  1621137480107
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              2.295122e+09             1.198526e+06     1
# 1              3.619586e+08             1.892825e+05     1
# 2              6.815023e+08             3.567596e+05     1
# 3              3.914550e+08             2.048980e+05     1
# 4              2.645620e+08             1.383854e+05     1
# ..                      ...                      ...   ...
# 195            4.180445e+09             2.152364e+06     1
# 196            1.166225e+10             5.982469e+06     1
# 197            7.902127e+09             4.061840e+06     1
# 198            2.158628e+09             1.112598e+06     1
# 199            2.144530e+09             1.106318e+06     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-ETC  2021-05-16T07:16:00  2021-05-16T16:16:00       122400.0
# 1    KRW-ETC  2021-05-16T07:15:00  2021-05-16T16:15:00       122150.0
# 2    KRW-ETC  2021-05-16T07:14:00  2021-05-16T16:14:00       122100.0
# 3    KRW-ETC  2021-05-16T07:13:00  2021-05-16T16:13:00       122100.0
# 4    KRW-ETC  2021-05-16T07:12:00  2021-05-16T16:12:00       122250.0
# ..       ...                  ...                  ...            ...
# 195  KRW-ETC  2021-05-16T04:01:00  2021-05-16T13:01:00       121250.0
# 196  KRW-ETC  2021-05-16T04:00:00  2021-05-16T13:00:00       121100.0
# 197  KRW-ETC  2021-05-16T03:59:00  2021-05-16T12:59:00       121100.0
# 198  KRW-ETC  2021-05-16T03:58:00  2021-05-16T12:58:00       120950.0
# 199  KRW-ETC  2021-05-16T03:57:00  2021-05-16T12:57:00       121150.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0      122600.0   122350.0     122500.0  1621149398235
# 1      122550.0   122100.0     122350.0  1621149360011
# 2      122200.0   122050.0     122100.0  1621149300262
# 3      122150.0   122050.0     122050.0  1621149240243
# 4      122250.0   122050.0     122100.0  1621149180136
# ..          ...        ...          ...            ...
# 195    121400.0   121200.0     121350.0  1621137719491
# 196    121400.0   121050.0     121300.0  1621137660125
# 197    121200.0   121050.0     121100.0  1621137600166
# 198    121250.0   120950.0     121100.0  1621137539958
# 199    121300.0   120650.0     120950.0  1621137480193
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              4.005782e+08              3271.249819     1
# 1              1.491421e+09             12186.595171     1
# 2              1.109646e+09              9088.327204     1
# 3              6.572834e+08              5382.770256     1
# 4              1.295929e+09             10609.959625     1
# ..                      ...                      ...   ...
# 195            6.279373e+08              5176.628017     1
# 196            1.190271e+09              9813.933523     1
# 197            6.541427e+08              5400.937463     1
# 198            7.440518e+08              6144.440248     1
# 199            1.228963e+09             10154.366464     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-OMG  2021-05-16T07:16:00  2021-05-16T16:16:00        12010.0
# 1    KRW-OMG  2021-05-16T07:15:00  2021-05-16T16:15:00        12010.0
# 2    KRW-OMG  2021-05-16T07:14:00  2021-05-16T16:14:00        12010.0
# 3    KRW-OMG  2021-05-16T07:13:00  2021-05-16T16:13:00        12000.0
# 4    KRW-OMG  2021-05-16T07:12:00  2021-05-16T16:12:00        12000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-OMG  2021-05-16T04:01:00  2021-05-16T13:01:00        11840.0
# 196  KRW-OMG  2021-05-16T04:00:00  2021-05-16T13:00:00        11840.0
# 197  KRW-OMG  2021-05-16T03:59:00  2021-05-16T12:59:00        11820.0
# 198  KRW-OMG  2021-05-16T03:58:00  2021-05-16T12:58:00        11830.0
# 199  KRW-OMG  2021-05-16T03:57:00  2021-05-16T12:57:00        11830.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       12020.0    12010.0      12020.0  1621149395280
# 1       12010.0    12010.0      12010.0  1621149357139
# 2       12020.0    12000.0      12010.0  1621149281817
# 3       12010.0    12000.0      12010.0  1621149231615
# 4       12000.0    11990.0      11990.0  1621149177190
# ..          ...        ...          ...            ...
# 195     11870.0    11820.0      11870.0  1621137713923
# 196     11870.0    11790.0      11850.0  1621137643600
# 197     11840.0    11820.0      11830.0  1621137599982
# 198     11840.0    11790.0      11820.0  1621137529547
# 199     11830.0    11820.0      11830.0  1621137477189
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              2.128104e+07              1770.469840     1
# 1              2.412494e+06               200.873749     1
# 2              1.888747e+07              1572.254140     1
# 3              1.423605e+07              1186.283474     1
# 4              8.194746e+06               683.334798     1
# ..                      ...                      ...   ...
# 195            1.297014e+07              1095.004857     1
# 196            4.229680e+07              3576.555709     1
# 197            2.278962e+06               192.561464     1
# 198            3.184434e+07              2696.098134     1
# 199            1.082084e+07               914.887219     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-SNT  2021-05-16T07:16:00  2021-05-16T16:16:00          210.0
# 1    KRW-SNT  2021-05-16T07:15:00  2021-05-16T16:15:00          210.0
# 2    KRW-SNT  2021-05-16T07:14:00  2021-05-16T16:14:00          210.0
# 3    KRW-SNT  2021-05-16T07:13:00  2021-05-16T16:13:00          211.0
# 4    KRW-SNT  2021-05-16T07:12:00  2021-05-16T16:12:00          210.0
# ..       ...                  ...                  ...            ...
# 195  KRW-SNT  2021-05-16T04:01:00  2021-05-16T13:01:00          205.0
# 196  KRW-SNT  2021-05-16T04:00:00  2021-05-16T13:00:00          205.0
# 197  KRW-SNT  2021-05-16T03:59:00  2021-05-16T12:59:00          204.0
# 198  KRW-SNT  2021-05-16T03:58:00  2021-05-16T12:58:00          204.0
# 199  KRW-SNT  2021-05-16T03:57:00  2021-05-16T12:57:00          203.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0         210.0      210.0        210.0  1621149398667
# 1         210.0      209.0        210.0  1621149352774
# 2         210.0      209.0        209.0  1621149297442
# 3         211.0      210.0        210.0  1621149238558
# 4         211.0      210.0        211.0  1621149180082
# ..          ...        ...          ...            ...
# 195       205.0      205.0        205.0  1621137720052
# 196       205.0      204.0        205.0  1621137656388
# 197       205.0      203.0        204.0  1621137598958
# 198       204.0      203.0        204.0  1621137521875
# 199       204.0      203.0        204.0  1621137479264
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              3.084806e+07            146895.529338     1
# 1              3.761560e+07            179152.533477     1
# 2              4.247855e+07            202389.158980     1
# 3              2.865484e+07            136152.184170     1
# 4              2.327227e+07            110761.323869     1
# ..                      ...                      ...   ...
# 195            1.017157e+08            496174.296837     1
# 196            8.138909e+07            397256.826956     1
# 197            1.490393e+08            730564.558546     1
# 198            1.454609e+07             71533.094113     1
# 199            8.054465e+06             39485.051479     1
#
# [200 rows x 11 columns]
#         market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-WAVES  2021-05-16T07:16:00  2021-05-16T16:16:00        39760.0
# 1    KRW-WAVES  2021-05-16T07:15:00  2021-05-16T16:15:00        39790.0
# 2    KRW-WAVES  2021-05-16T07:14:00  2021-05-16T16:14:00        39810.0
# 3    KRW-WAVES  2021-05-16T07:13:00  2021-05-16T16:13:00        39820.0
# 4    KRW-WAVES  2021-05-16T07:12:00  2021-05-16T16:12:00        39700.0
# ..         ...                  ...                  ...            ...
# 195  KRW-WAVES  2021-05-16T04:01:00  2021-05-16T13:01:00        39160.0
# 196  KRW-WAVES  2021-05-16T04:00:00  2021-05-16T13:00:00        39200.0
# 197  KRW-WAVES  2021-05-16T03:59:00  2021-05-16T12:59:00        39190.0
# 198  KRW-WAVES  2021-05-16T03:58:00  2021-05-16T12:58:00        39120.0
# 199  KRW-WAVES  2021-05-16T03:57:00  2021-05-16T12:57:00        39170.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       39800.0    39730.0      39730.0  1621149389160
# 1       39800.0    39760.0      39790.0  1621149359420
# 2       39810.0    39800.0      39800.0  1621149295305
# 3       39850.0    39810.0      39820.0  1621149238292
# 4       39830.0    39700.0      39830.0  1621149176529
# ..          ...        ...          ...            ...
# 195     39210.0    39160.0      39210.0  1621137720046
# 196     39210.0    39140.0      39140.0  1621137655063
# 197     39200.0    39140.0      39200.0  1621137598539
# 198     39200.0    39120.0      39190.0  1621137538867
# 199     39200.0    39120.0      39120.0  1621137474862
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              6.607509e+06               166.166006     1
# 1              1.595961e+07               401.257209     1
# 2              1.646236e+07               413.563428     1
# 3              2.247410e+07               564.298193     1
# 4              1.348465e+07               339.457288     1
# ..                      ...                      ...   ...
# 195            7.353687e+06               187.683229     1
# 196            2.477646e+07               632.231959     1
# 197            1.156863e+07               295.251525     1
# 198            6.677342e+06               170.486102     1
# 199            4.635255e+06               118.359726     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-XEM  2021-05-16T07:16:00  2021-05-16T16:16:00          384.0
# 1    KRW-XEM  2021-05-16T07:15:00  2021-05-16T16:15:00          383.0
# 2    KRW-XEM  2021-05-16T07:14:00  2021-05-16T16:14:00          383.0
# 3    KRW-XEM  2021-05-16T07:13:00  2021-05-16T16:13:00          383.0
# 4    KRW-XEM  2021-05-16T07:12:00  2021-05-16T16:12:00          382.0
# ..       ...                  ...                  ...            ...
# 195  KRW-XEM  2021-05-16T04:00:00  2021-05-16T13:00:00          375.0
# 196  KRW-XEM  2021-05-16T03:59:00  2021-05-16T12:59:00          375.0
# 197  KRW-XEM  2021-05-16T03:58:00  2021-05-16T12:58:00          375.0
# 198  KRW-XEM  2021-05-16T03:57:00  2021-05-16T12:57:00          375.0
# 199  KRW-XEM  2021-05-16T03:56:00  2021-05-16T12:56:00          374.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0         384.0      383.0        383.0  1621149395578
# 1         383.0      383.0        383.0  1621149360088
# 2         383.0      382.0        383.0  1621149299401
# 3         383.0      382.0        383.0  1621149234094
# 4         383.0      382.0        382.0  1621149176600
# ..          ...        ...          ...            ...
# 195       376.0      375.0        376.0  1621137656385
# 196       375.0      375.0        375.0  1621137582545
# 197       375.0      374.0        375.0  1621137540178
# 198       375.0      374.0        375.0  1621137480103
# 199       375.0      374.0        375.0  1621137413158
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.986397e+06              5173.009123     1
# 1              1.961317e+07             51209.323357     1
# 2              8.886599e+06             23235.402624     1
# 3              1.688404e+07             44128.385489     1
# 4              2.460785e+07             64415.477768     1
# ..                      ...                      ...   ...
# 195            9.523970e+06             25390.883257     1
# 196            8.886910e+06             23698.425869     1
# 197            4.687197e+07            124999.928304     1
# 198            1.448183e+07             38621.858656     1
# 199            3.104291e+06              8288.420940     1
#
# [200 rows x 11 columns]
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-QTUM  2021-05-16T07:16:00  2021-05-16T16:16:00        25620.0
# 1    KRW-QTUM  2021-05-16T07:15:00  2021-05-16T16:15:00        25590.0
# 2    KRW-QTUM  2021-05-16T07:14:00  2021-05-16T16:14:00        25560.0
# 3    KRW-QTUM  2021-05-16T07:13:00  2021-05-16T16:13:00        25560.0
# 4    KRW-QTUM  2021-05-16T07:12:00  2021-05-16T16:12:00        25540.0
# ..        ...                  ...                  ...            ...
# 195  KRW-QTUM  2021-05-16T04:01:00  2021-05-16T13:01:00        24880.0
# 196  KRW-QTUM  2021-05-16T04:00:00  2021-05-16T13:00:00        24810.0
# 197  KRW-QTUM  2021-05-16T03:59:00  2021-05-16T12:59:00        24730.0
# 198  KRW-QTUM  2021-05-16T03:58:00  2021-05-16T12:58:00        24770.0
# 199  KRW-QTUM  2021-05-16T03:57:00  2021-05-16T12:57:00        24780.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       25690.0    25600.0      25680.0  1621149398137
# 1       25620.0    25560.0      25620.0  1621149359511
# 2       25590.0    25560.0      25590.0  1621149296837
# 3       25570.0    25550.0      25550.0  1621149240057
# 4       25560.0    25530.0      25560.0  1621149180331
# ..          ...        ...          ...            ...
# 195     24900.0    24850.0      24890.0  1621137719680
# 196     24920.0    24810.0      24880.0  1621137658742
# 197     24810.0    24730.0      24810.0  1621137599838
# 198     24780.0    24720.0      24740.0  1621137540197
# 199     24790.0    24760.0      24760.0  1621137475907
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.905403e+08              7427.653470     1
# 1              1.786665e+08              6980.941478     1
# 2              9.808500e+07              3836.051464     1
# 3              3.608899e+07              1412.043802     1
# 4              4.658651e+07              1823.362451     1
# ..                      ...                      ...   ...
# 195            1.451764e+08              5834.174190     1
# 196            1.915772e+08              7704.424612     1
# 197            1.356107e+08              5474.984837     1
# 198            8.200801e+07              3312.340636     1
# 199            6.970198e+07              2813.192725     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-LSK  2021-05-16T07:16:00  2021-05-16T16:16:00         8240.0
# 1    KRW-LSK  2021-05-16T07:15:00  2021-05-16T16:15:00         8245.0
# 2    KRW-LSK  2021-05-16T07:14:00  2021-05-16T16:14:00         8240.0
# 3    KRW-LSK  2021-05-16T07:13:00  2021-05-16T16:13:00         8240.0
# 4    KRW-LSK  2021-05-16T07:12:00  2021-05-16T16:12:00         8235.0
# ..       ...                  ...                  ...            ...
# 195  KRW-LSK  2021-05-16T04:01:00  2021-05-16T13:01:00         8110.0
# 196  KRW-LSK  2021-05-16T04:00:00  2021-05-16T13:00:00         8090.0
# 197  KRW-LSK  2021-05-16T03:59:00  2021-05-16T12:59:00         8080.0
# 198  KRW-LSK  2021-05-16T03:58:00  2021-05-16T12:58:00         8075.0
# 199  KRW-LSK  2021-05-16T03:57:00  2021-05-16T12:57:00         8080.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        8275.0     8240.0       8275.0  1621149395413
# 1        8250.0     8245.0       8250.0  1621149358420
# 2        8245.0     8240.0       8245.0  1621149298544
# 3        8245.0     8240.0       8245.0  1621149236689
# 4        8240.0     8235.0       8240.0  1621149174477
# ..          ...        ...          ...            ...
# 195      8115.0     8075.0       8095.0  1621137719672
# 196      8115.0     8090.0       8115.0  1621137659386
# 197      8085.0     8080.0       8085.0  1621137599436
# 198      8080.0     8065.0       8080.0  1621137537988
# 199      8080.0     8075.0       8075.0  1621137479590
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              6.681693e+06               808.432148     1
# 1              1.371494e+07              1662.591502     1
# 2              6.779375e+06               822.649478     1
# 3              4.855920e+06               589.107811     1
# 4              5.213643e+06               633.090158     1
# ..                      ...                      ...   ...
# 195            2.696498e+07              3328.109131     1
# 196            1.159241e+07              1430.553490     1
# 197            2.320959e+07              2872.308013     1
# 198            2.621092e+07              3248.343274     1
# 199            3.676953e+06               455.238470     1
#
# [200 rows x 11 columns]
#         market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-STEEM  2021-05-16T07:16:00  2021-05-16T16:16:00         1085.0
# 1    KRW-STEEM  2021-05-16T07:15:00  2021-05-16T16:15:00         1085.0
# 2    KRW-STEEM  2021-05-16T07:14:00  2021-05-16T16:14:00         1085.0
# 3    KRW-STEEM  2021-05-16T07:13:00  2021-05-16T16:13:00         1085.0
# 4    KRW-STEEM  2021-05-16T07:12:00  2021-05-16T16:12:00         1085.0
# ..         ...                  ...                  ...            ...
# 195  KRW-STEEM  2021-05-16T03:58:00  2021-05-16T12:58:00         1070.0
# 196  KRW-STEEM  2021-05-16T03:57:00  2021-05-16T12:57:00         1070.0
# 197  KRW-STEEM  2021-05-16T03:56:00  2021-05-16T12:56:00         1065.0
# 198  KRW-STEEM  2021-05-16T03:55:00  2021-05-16T12:55:00         1070.0
# 199  KRW-STEEM  2021-05-16T03:54:00  2021-05-16T12:54:00         1070.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        1085.0     1085.0       1085.0  1621149372882
# 1        1085.0     1080.0       1085.0  1621149345016
# 2        1085.0     1085.0       1085.0  1621149296999
# 3        1085.0     1085.0       1085.0  1621149238841
# 4        1085.0     1085.0       1085.0  1621149178909
# ..          ...        ...          ...            ...
# 195      1075.0     1070.0       1075.0  1621137522092
# 196      1070.0     1070.0       1070.0  1621137446288
# 197      1070.0     1065.0       1070.0  1621137417762
# 198      1070.0     1065.0       1070.0  1621137355058
# 199      1070.0     1070.0       1070.0  1621137295479
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.190000e+05               109.677419     1
# 1              1.274965e+07             11765.840712     1
# 2              9.741419e+05               897.826619     1
# 3              7.885928e+06              7268.136301     1
# 4              3.989903e+07             36773.297432     1
# ..                      ...                      ...   ...
# 195            4.400000e+05               411.041078     1
# 196            1.031233e+06               963.769109     1
# 197            9.445757e+06              8838.968530     1
# 198            1.992583e+07             18623.044776     1
# 199            2.494830e+06              2331.616867     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-XLM  2021-05-16T07:16:00  2021-05-16T16:16:00          919.0
# 1    KRW-XLM  2021-05-16T07:15:00  2021-05-16T16:15:00          914.0
# 2    KRW-XLM  2021-05-16T07:14:00  2021-05-16T16:14:00          913.0
# 3    KRW-XLM  2021-05-16T07:13:00  2021-05-16T16:13:00          913.0
# 4    KRW-XLM  2021-05-16T07:12:00  2021-05-16T16:12:00          909.0
# ..       ...                  ...                  ...            ...
# 195  KRW-XLM  2021-05-16T04:01:00  2021-05-16T13:01:00          880.0
# 196  KRW-XLM  2021-05-16T04:00:00  2021-05-16T13:00:00          875.0
# 197  KRW-XLM  2021-05-16T03:59:00  2021-05-16T12:59:00          869.0
# 198  KRW-XLM  2021-05-16T03:58:00  2021-05-16T12:58:00          873.0
# 199  KRW-XLM  2021-05-16T03:57:00  2021-05-16T12:57:00          876.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0         923.0      918.0        922.0  1621149398406
# 1         919.0      914.0        918.0  1621149360662
# 2         915.0      912.0        915.0  1621149300112
# 3         914.0      912.0        912.0  1621149240210
# 4         914.0      908.0        913.0  1621149180277
# ..          ...        ...          ...            ...
# 195       882.0      879.0        881.0  1621137718801
# 196       880.0      875.0        880.0  1621137660177
# 197       876.0      868.0        876.0  1621137599670
# 198       874.0      868.0        869.0  1621137537859
# 199       876.0      873.0        873.0  1621137478865
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              8.849257e+08            961001.506449     1
# 1              8.818971e+08            962530.512761     1
# 2              3.428635e+08            375232.610722     1
# 3              2.377417e+08            260348.999281     1
# 4              4.869696e+08            534164.110116     1
# ..                      ...                      ...   ...
# 195            3.581682e+08            406713.129800     1
# 196            3.965203e+08            451437.116979     1
# 197            2.632081e+08            301962.048865     1
# 198            2.988930e+08            342902.743201     1
# 199            2.318823e+08            265311.125864     1
#
# [200 rows x 11 columns]
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-ARDR  2021-05-16T07:16:00  2021-05-16T16:16:00          415.0
# 1    KRW-ARDR  2021-05-16T07:15:00  2021-05-16T16:15:00          414.0
# 2    KRW-ARDR  2021-05-16T07:14:00  2021-05-16T16:14:00          414.0
# 3    KRW-ARDR  2021-05-16T07:13:00  2021-05-16T16:13:00          414.0
# 4    KRW-ARDR  2021-05-16T07:12:00  2021-05-16T16:12:00          413.0
# ..        ...                  ...                  ...            ...
# 195  KRW-ARDR  2021-05-16T03:45:00  2021-05-16T12:45:00          407.0
# 196  KRW-ARDR  2021-05-16T03:44:00  2021-05-16T12:44:00          409.0
# 197  KRW-ARDR  2021-05-16T03:43:00  2021-05-16T12:43:00          408.0
# 198  KRW-ARDR  2021-05-16T03:42:00  2021-05-16T12:42:00          409.0
# 199  KRW-ARDR  2021-05-16T03:41:00  2021-05-16T12:41:00          408.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0         415.0      415.0        415.0  1621149378796
# 1         415.0      414.0        415.0  1621149346136
# 2         414.0      413.0        414.0  1621149298373
# 3         414.0      413.0        413.0  1621149234305
# 4         414.0      413.0        413.0  1621149173743
# ..          ...        ...          ...            ...
# 195       407.0      406.0        406.0  1621136754704
# 196       409.0      408.0        408.0  1621136691797
# 197       409.0      408.0        409.0  1621136631543
# 198       409.0      407.0        408.0  1621136575043
# 199       408.0      408.0        408.0  1621136475731
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              2.231700e+04                53.775904     1
# 1              2.585323e+06              6244.307085     1
# 2              1.134156e+07             27397.410347     1
# 3              2.103970e+06              5083.504317     1
# 4              5.746385e+05              1388.150100     1
# ..                      ...                      ...   ...
# 195            9.674946e+06             23771.737427     1
# 196            7.168787e+05              1756.544007     1
# 197            5.997555e+05              1466.992665     1
# 198            2.862029e+07             70185.130883     1
# 199            5.429309e+06             13307.129362     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-KMD  2021-05-16T07:16:00  2021-05-16T16:16:00         2985.0
# 1    KRW-KMD  2021-05-16T07:15:00  2021-05-16T16:15:00         2985.0
# 2    KRW-KMD  2021-05-16T07:14:00  2021-05-16T16:14:00         2995.0
# 3    KRW-KMD  2021-05-16T07:13:00  2021-05-16T16:13:00         3000.0
# 4    KRW-KMD  2021-05-16T07:12:00  2021-05-16T16:12:00         3000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-KMD  2021-05-16T03:50:00  2021-05-16T12:50:00         2930.0
# 196  KRW-KMD  2021-05-16T03:49:00  2021-05-16T12:49:00         2930.0
# 197  KRW-KMD  2021-05-16T03:48:00  2021-05-16T12:48:00         2920.0
# 198  KRW-KMD  2021-05-16T03:47:00  2021-05-16T12:47:00         2920.0
# 199  KRW-KMD  2021-05-16T03:46:00  2021-05-16T12:46:00         2930.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        2985.0     2985.0       2985.0  1621149371039
# 1        2990.0     2985.0       2985.0  1621149337527
# 2        2995.0     2990.0       2990.0  1621149293184
# 3        3000.0     2995.0       2995.0  1621149239116
# 4        3000.0     2995.0       2995.0  1621149169762
# ..          ...        ...          ...            ...
# 195      2930.0     2930.0       2930.0  1621137016579
# 196      2930.0     2930.0       2930.0  1621136982245
# 197      2935.0     2920.0       2930.0  1621136937757
# 198      2925.0     2920.0       2920.0  1621136855065
# 199      2930.0     2920.0       2930.0  1621136811934
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              4.575807e+05               153.293382     1
# 1              2.106920e+07              7058.078908     1
# 2              1.442527e+07              4822.393035     1
# 3              7.578405e+06              2530.349469     1
# 4              1.468103e+06               489.701397     1
# ..                      ...                      ...   ...
# 195            2.014174e+05                68.743156     1
# 196            3.984475e+06              1359.889032     1
# 197            1.358122e+07              4636.782454     1
# 198            9.749888e+05               333.889816     1
# 199            2.993931e+05               102.193617     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-ARK  2021-05-16T07:16:00  2021-05-16T16:16:00         2095.0
# 1    KRW-ARK  2021-05-16T07:15:00  2021-05-16T16:15:00         2080.0
# 2    KRW-ARK  2021-05-16T07:14:00  2021-05-16T16:14:00         2090.0
# 3    KRW-ARK  2021-05-16T07:13:00  2021-05-16T16:13:00         2090.0
# 4    KRW-ARK  2021-05-16T07:12:00  2021-05-16T16:12:00         2090.0
# ..       ...                  ...                  ...            ...
# 195  KRW-ARK  2021-05-16T03:33:00  2021-05-16T12:33:00         2040.0
# 196  KRW-ARK  2021-05-16T03:32:00  2021-05-16T12:32:00         2035.0
# 197  KRW-ARK  2021-05-16T03:31:00  2021-05-16T12:31:00         2040.0
# 198  KRW-ARK  2021-05-16T03:30:00  2021-05-16T12:30:00         2045.0
# 199  KRW-ARK  2021-05-16T03:29:00  2021-05-16T12:29:00         2040.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        2095.0     2095.0       2095.0  1621149365506
# 1        2095.0     2080.0       2095.0  1621149343259
# 2        2090.0     2075.0       2080.0  1621149292637
# 3        2090.0     2090.0       2090.0  1621149229035
# 4        2090.0     2090.0       2090.0  1621149133220
# ..          ...        ...          ...            ...
# 195      2040.0     2035.0       2040.0  1621136037867
# 196      2035.0     2035.0       2035.0  1621135947689
# 197      2040.0     2040.0       2040.0  1621135906771
# 198      2045.0     2040.0       2040.0  1621135854870
# 199      2050.0     2040.0       2045.0  1621135799918
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              4.997501e+04                23.854421     1
# 1              2.995190e+06              1438.895301     1
# 2              1.012610e+07              4848.361427     1
# 3              2.142014e+06              1024.887080     1
# 4              1.770507e+05                84.713256     1
# ..                      ...                      ...   ...
# 195            5.000545e+06              2451.288446     1
# 196            7.048125e+06              3463.452129     1
# 197            2.901084e+06              1422.100063     1
# 198            5.473157e+05               268.238085     1
# 199            6.582984e+05               322.594127     1
#
# [200 rows x 11 columns]
#         market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-STORJ  2021-05-16T07:16:00  2021-05-16T16:16:00         2150.0
# 1    KRW-STORJ  2021-05-16T07:14:00  2021-05-16T16:14:00         2150.0
# 2    KRW-STORJ  2021-05-16T07:13:00  2021-05-16T16:13:00         2150.0
# 3    KRW-STORJ  2021-05-16T07:12:00  2021-05-16T16:12:00         2150.0
# 4    KRW-STORJ  2021-05-16T07:11:00  2021-05-16T16:11:00         2160.0
# ..         ...                  ...                  ...            ...
# 195  KRW-STORJ  2021-05-16T03:46:00  2021-05-16T12:46:00         2050.0
# 196  KRW-STORJ  2021-05-16T03:45:00  2021-05-16T12:45:00         2050.0
# 197  KRW-STORJ  2021-05-16T03:43:00  2021-05-16T12:43:00         2050.0
# 198  KRW-STORJ  2021-05-16T03:42:00  2021-05-16T12:42:00         2045.0
# 199  KRW-STORJ  2021-05-16T03:41:00  2021-05-16T12:41:00         2045.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        2150.0     2150.0       2150.0  1621149384368
# 1        2150.0     2150.0       2150.0  1621149263062
# 2        2150.0     2150.0       2150.0  1621149215488
# 3        2150.0     2150.0       2150.0  1621149174423
# 4        2160.0     2150.0       2150.0  1621149085995
# ..          ...        ...          ...            ...
# 195      2060.0     2050.0       2055.0  1621136814799
# 196      2050.0     2050.0       2050.0  1621136741146
# 197      2050.0     2050.0       2050.0  1621136587216
# 198      2045.0     2045.0       2045.0  1621136538132
# 199      2045.0     2045.0       2045.0  1621136517378
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.756868e+06               817.148124     1
# 1              8.573365e+05               398.761157     1
# 2              2.082895e+06               968.788515     1
# 3              6.525749e+05               303.523225     1
# 4              1.387362e+07              6441.118422     1
# ..                      ...                      ...   ...
# 195            1.689151e+07              8213.812618     1
# 196            2.717695e+05               132.570464     1
# 197            3.594035e+05               175.318801     1
# 198            1.001302e+05                48.963441     1
# 199            1.054437e+06               515.617307     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-GRS  2021-05-16T07:16:00  2021-05-16T16:16:00         1450.0
# 1    KRW-GRS  2021-05-16T07:15:00  2021-05-16T16:15:00         1450.0
# 2    KRW-GRS  2021-05-16T07:14:00  2021-05-16T16:14:00         1450.0
# 3    KRW-GRS  2021-05-16T07:12:00  2021-05-16T16:12:00         1445.0
# 4    KRW-GRS  2021-05-16T07:11:00  2021-05-16T16:11:00         1445.0
# ..       ...                  ...                  ...            ...
# 195  KRW-GRS  2021-05-16T03:50:00  2021-05-16T12:50:00         1420.0
# 196  KRW-GRS  2021-05-16T03:49:00  2021-05-16T12:49:00         1420.0
# 197  KRW-GRS  2021-05-16T03:48:00  2021-05-16T12:48:00         1425.0
# 198  KRW-GRS  2021-05-16T03:47:00  2021-05-16T12:47:00         1415.0
# 199  KRW-GRS  2021-05-16T03:46:00  2021-05-16T12:46:00         1415.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        1450.0     1445.0       1445.0  1621149399608
# 1        1450.0     1450.0       1450.0  1621149300608
# 2        1450.0     1450.0       1450.0  1621149269722
# 3        1445.0     1445.0       1445.0  1621149144247
# 4        1445.0     1445.0       1445.0  1621149096937
# ..          ...        ...          ...            ...
# 195      1425.0     1415.0       1415.0  1621137057004
# 196      1420.0     1420.0       1420.0  1621136991427
# 197      1425.0     1425.0       1425.0  1621136921029
# 198      1420.0     1415.0       1420.0  1621136858598
# 199      1415.0     1415.0       1415.0  1621136809646
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              2.156902e+07             14875.603617     1
# 1              1.000000e+04                 6.896552     1
# 2              4.485670e+06              3093.565631     1
# 3              8.933539e+03                 6.182380     1
# 4              1.568965e+05               108.578887     1
# ..                      ...                      ...   ...
# 195            1.058314e+07              7444.209014     1
# 196            1.258694e+04                 8.864040     1
# 197            7.345000e+04                51.543860     1
# 198            8.464650e+06              5970.847379     1
# 199            5.543946e+06              3917.983272     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-REP  2021-05-16T07:15:00  2021-05-16T16:15:00        44480.0
# 1    KRW-REP  2021-05-16T07:14:00  2021-05-16T16:14:00        44480.0
# 2    KRW-REP  2021-05-16T07:13:00  2021-05-16T16:13:00        44570.0
# 3    KRW-REP  2021-05-16T07:12:00  2021-05-16T16:12:00        44510.0
# 4    KRW-REP  2021-05-16T07:09:00  2021-05-16T16:09:00        44510.0
# ..       ...                  ...                  ...            ...
# 195  KRW-REP  2021-05-16T03:30:00  2021-05-16T12:30:00        43650.0
# 196  KRW-REP  2021-05-16T03:29:00  2021-05-16T12:29:00        43660.0
# 197  KRW-REP  2021-05-16T03:28:00  2021-05-16T12:28:00        44000.0
# 198  KRW-REP  2021-05-16T03:27:00  2021-05-16T12:27:00        43630.0
# 199  KRW-REP  2021-05-16T03:26:00  2021-05-16T12:26:00        43730.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       44550.0    44480.0      44550.0  1621149352052
# 1       44480.0    44470.0      44470.0  1621149282792
# 2       44570.0    44480.0      44480.0  1621149224182
# 3       44510.0    44480.0      44480.0  1621149159725
# 4       44510.0    44510.0      44510.0  1621148989936
# ...
# ..        ...                  ...                  ...            ...
# 195  KRW-DOGE  2021-05-16T04:01:00  2021-05-16T13:01:00          652.0
# 196  KRW-DOGE  2021-05-16T04:00:00  2021-05-16T13:00:00          649.0
# 197  KRW-DOGE  2021-05-16T03:59:00  2021-05-16T12:59:00          649.0
# 198  KRW-DOGE  2021-05-16T03:58:00  2021-05-16T12:58:00          649.0
# 199  KRW-DOGE  2021-05-16T03:57:00  2021-05-16T12:57:00          648.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0         652.0      651.0        651.0  1621149413591
# 1         652.0      650.0        651.0  1621149359082
# 2         652.0      650.0        650.0  1621149300291
# 3         652.0      651.0        651.0  1621149239268
# 4         652.0      651.0        651.0  1621149180196
# ..          ...        ...          ...            ...
# 195       652.0      651.0        651.0  1621137719583
# 196       652.0      649.0        652.0  1621137659702
# 197       650.0      649.0        649.0  1621137600080
# 198       650.0      648.0        650.0  1621137540261
# 199       650.0      648.0        650.0  1621137479878
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              2.852581e+08             4.380367e+05     1
# 1              5.389957e+08             8.281546e+05     1
# 2              6.332577e+08             9.730492e+05     1
# 3              2.820000e+08             4.331316e+05     1
# 4              8.660938e+08             1.330288e+06     1
# ..                      ...                      ...   ...
# 195            7.757100e+08             1.190932e+06     1
# 196            2.951260e+09             4.535399e+06     1
# 197            3.372961e+08             5.191662e+05     1
# 198            4.092222e+08             6.302583e+05     1
# 199            8.612790e+08             1.327235e+06     1
#
# [200 rows x 11 columns]
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-STRK  2021-05-16T07:16:00  2021-05-16T16:16:00        66320.0
# 1    KRW-STRK  2021-05-16T07:15:00  2021-05-16T16:15:00        66440.0
# 2    KRW-STRK  2021-05-16T07:14:00  2021-05-16T16:14:00        66450.0
# 3    KRW-STRK  2021-05-16T07:13:00  2021-05-16T16:13:00        66300.0
# 4    KRW-STRK  2021-05-16T07:12:00  2021-05-16T16:12:00        66290.0
# ..        ...                  ...                  ...            ...
# 195  KRW-STRK  2021-05-16T04:00:00  2021-05-16T13:00:00        65090.0
# 196  KRW-STRK  2021-05-16T03:59:00  2021-05-16T12:59:00        65080.0
# 197  KRW-STRK  2021-05-16T03:58:00  2021-05-16T12:58:00        65080.0
# 198  KRW-STRK  2021-05-16T03:57:00  2021-05-16T12:57:00        65280.0
# 199  KRW-STRK  2021-05-16T03:56:00  2021-05-16T12:56:00        65100.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       66370.0    66320.0      66320.0  1621149406072
# 1       66440.0    66310.0      66320.0  1621149347605
# 2       66450.0    66300.0      66440.0  1621149299702
# 3       66450.0    66290.0      66440.0  1621149240266
# 4       66300.0    66250.0      66300.0  1621149179794
# ..          ...        ...          ...            ...
# 195     65110.0    65090.0      65110.0  1621137653523
# 196     65090.0    65080.0      65090.0  1621137599983
# 197     65080.0    65080.0      65080.0  1621137510898
# 198     65280.0    65080.0      65080.0  1621137473385
# 199     65290.0    65100.0      65290.0  1621137411906
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              5.708945e+06                86.081718     1
# 1              8.765966e+06               131.960828     1
# 2              2.765693e+06                41.695158     1
# 3              2.248788e+07               338.842761     1
# 4              4.071903e+07               614.269600     1
# ..                      ...                      ...   ...
# 195            6.380098e+06                97.997651     1
# 196            2.379569e+06                36.558470     1
# 197            3.301683e+05                 5.073268     1
# 198            9.231295e+06               141.817783     1
# 199            3.226506e+06                49.428196     1
#
# [200 rows x 11 columns]
#          market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-PUNDIX  2021-05-16T07:16:00  2021-05-16T16:16:00         2990.0
# 1    KRW-PUNDIX  2021-05-16T07:15:00  2021-05-16T16:15:00         2990.0
# 2    KRW-PUNDIX  2021-05-16T07:14:00  2021-05-16T16:14:00         2985.0
# 3    KRW-PUNDIX  2021-05-16T07:13:00  2021-05-16T16:13:00         2990.0
# 4    KRW-PUNDIX  2021-05-16T07:12:00  2021-05-16T16:12:00         2995.0
# ..          ...                  ...                  ...            ...
# 195  KRW-PUNDIX  2021-05-16T04:00:00  2021-05-16T13:00:00         2945.0
# 196  KRW-PUNDIX  2021-05-16T03:59:00  2021-05-16T12:59:00         2955.0
# 197  KRW-PUNDIX  2021-05-16T03:58:00  2021-05-16T12:58:00         2955.0
# 198  KRW-PUNDIX  2021-05-16T03:57:00  2021-05-16T12:57:00         2950.0
# 199  KRW-PUNDIX  2021-05-16T03:56:00  2021-05-16T12:56:00         2950.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        2990.0     2990.0       2990.0  1621149398784
# 1        2990.0     2990.0       2990.0  1621149351248
# 2        2990.0     2985.0       2990.0  1621149296923
# 3        2990.0     2985.0       2985.0  1621149238759
# 4        2995.0     2990.0       2990.0  1621149176211
# ..          ...        ...          ...            ...
# 195      2945.0     2940.0       2945.0  1621137656609
# 196      2955.0     2950.0       2950.0  1621137598406
# 197      2955.0     2950.0       2955.0  1621137539418
# 198      2955.0     2950.0       2955.0  1621137476007
# 199      2950.0     2950.0       2950.0  1621137417354
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.832387e+07              6128.385974     1
# 1              3.834383e+06              1282.402440     1
# 2              3.605378e+06              1207.775826     1
# 3              9.447729e+06              3159.924882     1
# 4              3.301197e+07             11040.217207     1
# ..                      ...                      ...   ...
# 195            1.810669e+07              6148.715293     1
# 196            1.791316e+06               607.168420     1
# 197            1.168279e+07              3959.939951     1
# 198            2.528470e+06               856.534872     1
# 199            1.554402e+07              5269.158656     1
#
# [200 rows x 11 columns]
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-FLOW  2021-05-16T07:16:00  2021-05-16T16:16:00        30680.0
# 1    KRW-FLOW  2021-05-16T07:15:00  2021-05-16T16:15:00        30670.0
# 2    KRW-FLOW  2021-05-16T07:14:00  2021-05-16T16:14:00        30670.0
# 3    KRW-FLOW  2021-05-16T07:13:00  2021-05-16T16:13:00        30660.0
# 4    KRW-FLOW  2021-05-16T07:12:00  2021-05-16T16:12:00        30650.0
# ..        ...                  ...                  ...            ...
# 195  KRW-FLOW  2021-05-16T03:50:00  2021-05-16T12:50:00        30170.0
# 196  KRW-FLOW  2021-05-16T03:49:00  2021-05-16T12:49:00        30160.0
# 197  KRW-FLOW  2021-05-16T03:48:00  2021-05-16T12:48:00        30160.0
# 198  KRW-FLOW  2021-05-16T03:47:00  2021-05-16T12:47:00        30160.0
# 199  KRW-FLOW  2021-05-16T03:46:00  2021-05-16T12:46:00        30160.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0       30680.0    30680.0      30680.0  1621149408163
# 1       30670.0    30670.0      30670.0  1621149348319
# 2       30690.0    30660.0      30660.0  1621149300274
# 3       30680.0    30650.0      30660.0  1621149232196
# 4       30650.0    30650.0      30650.0  1621149167294
# ..          ...        ...          ...            ...
# 195     30190.0    30170.0      30190.0  1621137049144
# 196     30170.0    30160.0      30170.0  1621136997567
# 197     30160.0    30160.0      30160.0  1621136935360
# 198     30160.0    30160.0      30160.0  1621136838427
# 199     30160.0    30160.0      30160.0  1621136768721
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.859293e+06                60.602758     1
# 1              2.031631e+07               662.416289     1
# 2              1.560210e+07               508.766411     1
# 3              7.380021e+06               240.696936     1
# 4              1.501849e+06                48.999960     1
# ..                      ...                      ...   ...
# 195            1.000312e+07               331.343582     1
# 196            4.739913e+06               157.155731     1
# 197            5.971480e+06               197.993365     1
# 198            6.032000e+05                20.000000     1
# 199            2.074207e+05                 6.877345     1
#
# [200 rows x 11 columns]
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-DAWN  2021-05-16T07:16:00  2021-05-16T16:16:00         6255.0
# 1    KRW-DAWN  2021-05-16T07:15:00  2021-05-16T16:15:00         6250.0
# 2    KRW-DAWN  2021-05-16T07:14:00  2021-05-16T16:14:00         6245.0
# 3    KRW-DAWN  2021-05-16T07:13:00  2021-05-16T16:13:00         6255.0
# 4    KRW-DAWN  2021-05-16T07:12:00  2021-05-16T16:12:00         6250.0
# ..        ...                  ...                  ...            ...
# 195  KRW-DAWN  2021-05-16T04:01:00  2021-05-16T13:01:00         6145.0
# 196  KRW-DAWN  2021-05-16T04:00:00  2021-05-16T13:00:00         6135.0
# 197  KRW-DAWN  2021-05-16T03:59:00  2021-05-16T12:59:00         6135.0
# 198  KRW-DAWN  2021-05-16T03:58:00  2021-05-16T12:58:00         6125.0
# 199  KRW-DAWN  2021-05-16T03:57:00  2021-05-16T12:57:00         6130.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        6260.0     6255.0       6260.0  1621149410460
# 1        6260.0     6250.0       6255.0  1621149357178
# 2        6250.0     6245.0       6250.0  1621149297419
# 3        6255.0     6245.0       6245.0  1621149237001
# 4        6255.0     6250.0       6255.0  1621149175706
# ..          ...        ...          ...            ...
# 195      6150.0     6145.0       6150.0  1621137713858
# 196      6145.0     6135.0       6140.0  1621137659846
# 197      6135.0     6125.0       6130.0  1621137593790
# 198      6135.0     6125.0       6135.0  1621137540115
# 199      6130.0     6125.0       6125.0  1621137478920
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.448376e+07              2315.191207     1
# 1              2.314104e+07              3700.706065     1
# 2              3.416127e+07              5467.864790     1
# 3              2.425297e+07              3879.828176     1
# 4              2.324445e+07              3719.105075     1
# ..                      ...                      ...   ...
# 195            1.483147e+07              2412.205893     1
# 196            1.457079e+07              2372.548657     1
# 197            2.776213e+07              4528.712039     1
# 198            1.487121e+07              2426.040896     1
# 199            1.704323e+07              2781.928008     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-AXS  2021-05-16T07:15:00  2021-05-16T16:15:00         8430.0
# 1    KRW-AXS  2021-05-16T07:14:00  2021-05-16T16:14:00         8435.0
# 2    KRW-AXS  2021-05-16T07:13:00  2021-05-16T16:13:00         8430.0
# 3    KRW-AXS  2021-05-16T07:12:00  2021-05-16T16:12:00         8440.0
# 4    KRW-AXS  2021-05-16T07:11:00  2021-05-16T16:11:00         8465.0
# ..       ...                  ...                  ...            ...
# 195  KRW-AXS  2021-05-16T03:51:00  2021-05-16T12:51:00         8230.0
# 196  KRW-AXS  2021-05-16T03:50:00  2021-05-16T12:50:00         8230.0
# 197  KRW-AXS  2021-05-16T03:49:00  2021-05-16T12:49:00         8230.0
# 198  KRW-AXS  2021-05-16T03:48:00  2021-05-16T12:48:00         8225.0
# 199  KRW-AXS  2021-05-16T03:47:00  2021-05-16T12:47:00         8250.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        8430.0     8430.0       8430.0  1621149307533
# 1        8435.0     8430.0       8435.0  1621149294956
# 2        8435.0     8430.0       8435.0  1621149228041
# 3        8445.0     8425.0       8425.0  1621149175082
# 4        8465.0     8440.0       8445.0  1621149112170
# ..          ...        ...          ...            ...
# 195      8230.0     8230.0       8230.0  1621137082306
# 196      8230.0     8230.0       8230.0  1621137048589
# 197      8230.0     8230.0       8230.0  1621136991403
# 198      8225.0     8225.0       8225.0  1621136913233
# 199      8250.0     8250.0       8250.0  1621136842458
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              7.587000e+05                90.000000     1
# 1              7.663902e+06               908.881047     1
# 2              4.219117e+06               500.330951     1
# 3              1.753118e+06               207.871645     1
# 4              5.542287e+06               655.880608     1
# ..                      ...                      ...   ...
# 195            2.116303e+05                25.714500     1
# 196            1.213000e+06               147.387606     1
# 197            1.057054e+06               128.439076     1
# 198            5.575855e+04                 6.779155     1
# 199            9.990005e+03                 1.210910     1
#
# [200 rows x 11 columns]
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-STX  2021-05-16T07:16:00  2021-05-16T16:16:00         1990.0
# 1    KRW-STX  2021-05-16T07:15:00  2021-05-16T16:15:00         1990.0
# 2    KRW-STX  2021-05-16T07:14:00  2021-05-16T16:14:00         1990.0
# 3    KRW-STX  2021-05-16T07:13:00  2021-05-16T16:13:00         1990.0
# 4    KRW-STX  2021-05-16T07:12:00  2021-05-16T16:12:00         1990.0
# ..       ...                  ...                  ...            ...
# 195  KRW-STX  2021-05-16T03:56:00  2021-05-16T12:56:00         1955.0
# 196  KRW-STX  2021-05-16T03:55:00  2021-05-16T12:55:00         1965.0
# 197  KRW-STX  2021-05-16T03:54:00  2021-05-16T12:54:00         1970.0
# 198  KRW-STX  2021-05-16T03:53:00  2021-05-16T12:53:00         1970.0
# 199  KRW-STX  2021-05-16T03:52:00  2021-05-16T12:52:00         1970.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0        1990.0     1990.0       1990.0  1621149400097
# 1        1990.0     1990.0       1990.0  1621149345570
# 2        1990.0     1990.0       1990.0  1621149275642
# 3        1990.0     1985.0       1985.0  1621149222276
# 4        1990.0     1990.0       1990.0  1621149160122
# ..          ...        ...          ...            ...
# 195      1965.0     1955.0       1965.0  1621137409002
# 196      1965.0     1955.0       1960.0  1621137359385
# 197      1970.0     1960.0       1965.0  1621137297726
# 198      1970.0     1970.0       1970.0  1621137229703
# 199      1970.0     1970.0       1970.0  1621137125666
#
#      candle_acc_trade_price  candle_acc_trade_volume  unit
# 0              1.042866e+07              5240.531172     1
# 1              8.785320e+06              4414.733876     1
# 2              4.210684e+06              2115.921408     1
# 3              5.193508e+06              2614.668665     1
# 4              2.249472e+07             11303.881347     1
# ..                      ...                      ...   ...
# 195            2.877959e+06              1467.855636     1
# 196            6.634602e+06              3385.094038     1
# 197            2.481302e+06              1264.533471     1
# 198            1.319900e+06               670.000000     1
# 199            1.000000e+06               507.614213     1
#
# [200 rows x 11 columns]
# ['KRW-CHZ', 598.0, 574.0, -4.013]

# %%
#잔고의 10%를 투자
#(재확인필요  - 조사했던 현재가가 구매직전의 가격보다 높을경우 구매하지않고 다음으로 넘어간다.
#
#잔고의 10% 설정
for a in balance():
    if a['currency'] == 'KRW':
        print(a['balance'])
        buy_amount = float(a['balance'])*0.10
        print(round(buy_amount,-2))
        buy_amount = round(buy_amount,-2)
# Out:
# [{'currency': 'KRW', 'balance': '728547.065354', 'locked': '0.0', 'avg_buy_price': '0', 'avg_buy_price_modified': True, 'unit_currency': 'KRW'}, {'currency': 'CHZ', 'balance': '0.0', 'locked': '468.85813148', 'avg_buy_price': '578', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}]
# 728547.065354
# 72900.0

# %%
#해당 코인을 시장가에 구매
# buy_market()
buy_market(decrease_top_score_ticker[0],buy_amount)
time.sleep(3)
# Out:
# {'uuid': 'b611ce00-b591-4028-807a-7d838da97f5e', 'side': 'bid', 'ord_type': 'price', 'price': '72900.0', 'state': 'wait', 'market': 'KRW-CHZ', 'created_at': '2021-05-16T16:17:25+09:00', 'volume': None, 'remaining_volume': None, 'reserved_fee': '36.45', 'remaining_fee': '36.45', 'paid_fee': '0.0', 'locked': '72936.45', 'executed_volume': '0.0', 'trades_count': 0}

# %%
def price_trim(price_trim):
    if price_trim<10:
        price_trim = round(price_trim,2)
    #10원이상~100원 미만 - [소수점첫째자리]
    elif price_trim<100:
        price_trim = round(price_trim,1)
    #100원이상 - [1원단위]
    elif price_trim<1000:
        price_trim = round(price_trim)
    #1000원이상 - [5원단위]
    elif price_trim<10000:
        price_trim = round(price_trim,-1)
    #10000원이상 - [10원단위]
    elif price_trim<100000:
        price_trim = round(price_trim,-1)
    #100000원이상 - [50원단위]
    elif price_trim<500000:
        price_trim = round(price_trim,-2)
    #500000원이상 - [100원단위]
    elif price_trim<10000000:
        price_trim = round(price_trim,-2)
    #10000000원이상 - [1000원단위]
    else:
        price_trim = round(price_trim,-3)
    return price_trim

# %%
#구매한 코인이 2% 상승했을 때 판매
#판매해야하는 가격 
sell_price = price_trim(coin_price(decrease_top_score_ticker[0])*1.02)
#가지고있는 코인갯수
for a in balance():
    if a['currency'] == decrease_top_score_ticker[0].replace("KRW-",""):
        sell_balance = a['balance']
#지정가에 판매
sell_limit(decrease_top_score_ticker[0],sell_balance,sell_price)

#30분단위로 반복
# Out:
# [{'currency': 'KRW', 'balance': '655610.61535432', 'locked': '0.0', 'avg_buy_price': '0', 'avg_buy_price_modified': True, 'unit_currency': 'KRW'}, {'currency': 'CHZ', 'balance': '127.00348432', 'locked': '468.85813148', 'avg_buy_price': '577.15', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}]
# {'uuid': '3e583e38-d8d3-43e3-aec6-50427e1c9b9b', 'side': 'ask', 'ord_type': 'limit', 'price': '585.0', 'state': 'wait', 'market': 'KRW-CHZ', 'created_at': '2021-05-16T16:17:29+09:00', 'volume': '127.00348432', 'remaining_volume': '127.00348432', 'reserved_fee': '0.0', 'remaining_fee': '0.0', 'paid_fee': '0.0', 'locked': '127.00348432', 'executed_volume': '0.0', 'trades_count': 0}
# {'uuid': '3e583e38-d8d3-43e3-aec6-50427e1c9b9b',
#  'side': 'ask',
#  'ord_type': 'limit',
#  'price': '585.0',
#  'state': 'wait',
#  'market': 'KRW-CHZ',
#  'created_at': '2021-05-16T16:17:29+09:00',
#  'volume': '127.00348432',
#  'remaining_volume': '127.00348432',
#  'reserved_fee': '0.0',
#  'remaining_fee': '0.0',
#  'paid_fee': '0.0',
#  'locked': '127.00348432',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %% [markdown]
# ### 6. 투자아이디어 프로그램 제작

# %%
def price_trim(price_trim):
    if price_trim<10:
        price_trim = round(price_trim,2)
    #10원이상~100원 미만 - [소수점첫째자리]
    elif price_trim<100:
        price_trim = round(price_trim,1)
    #100원이상 - [1원단위]
    elif price_trim<1000:
        price_trim = round(price_trim)
    #1000원이상 - [5원단위]
    elif price_trim<10000:
        price_trim = round(price_trim,-1)
    #10000원이상 - [10원단위]
    elif price_trim<100000:
        price_trim = round(price_trim,-1)
    #100000원이상 - [50원단위]
    elif price_trim<500000:
        price_trim = round(price_trim,-2)
    #500000원이상 - [100원단위]
    elif price_trim<10000000:
        price_trim = round(price_trim,-2)
    #10000000원이상 - [1000원단위]
    else:
        price_trim = round(price_trim,-3)
    return price_trim


import time 
while True:
    
    try:
            #1분봉으로 200분 안에 제일 하락을 많이 한 코인을 찾기
        # coin_history("KRW-BTC","minutes",30)
        tickers = coins("KRW")
        decrease_top_score =0.001
        # ticker = "KRW-BTC"
        for ticker in tickers:
            coin_1_m = coin_history(ticker,'minutes',1)
#             print(coin_1_m)

            max_high_price = coin_1_m["high_price"].max()
            now_price = coin_price(ticker)
        #     print(ticker)
        #     print(max_high_price)
        #     print(now_price)
        #     print("하락률 : " + str(round(((1-(now_price/max_high_price))*100),3)) + "%")
            decrease_percent = round(((1-(now_price/max_high_price))*100),3)
            if decrease_percent > decrease_top_score :
                decrease_top_score = decrease_percent
                decrease_top_score_ticker = [ticker,max_high_price,now_price,(-1)*decrease_percent]


        print(decrease_top_score_ticker)

        for a in balance():
            if a['currency'] == 'KRW':
                print(a['balance'])
                buy_amount = float(a['balance'])*0.10
                print(round(buy_amount,-2))
                buy_amount = round(buy_amount,-2)

        #해당 코인을 시장가에 구매
        # buy_market()
        buy_market(decrease_top_score_ticker[0],buy_amount)
        time.sleep(3)

        #구매한 코인이 2% 상승했을 때 판매
        #판매해야하는 가격 
        sell_price = price_trim(coin_price(decrease_top_score_ticker[0])*1.02)
        #가지고있는 코인갯수
        for a in balance():
            if a['currency'] == decrease_top_score_ticker[0].replace("KRW-",""):
                sell_balance = a['balance']
        #지정가에 판매
        sell_limit(decrease_top_score_ticker[0],sell_balance,sell_price)

        time.sleep(180)
    except:
        time.sleep(180)
    #30분단위로 반복
# Out:
# ['KRW-CHZ', 598.0, 571.0, -4.515]
# [{'currency': 'KRW', 'balance': '996868.60685479', 'locked': '0.0', 'avg_buy_price': '0', 'avg_buy_price_modified': True, 'unit_currency': 'KRW'}]
# 996868.60685479
# 99700.0
# {'uuid': '64d7687a-ec69-4ed9-9d98-7d8fe80dd5e2', 'side': 'bid', 'ord_type': 'price', 'price': '99700.0', 'state': 'wait', 'market': 'KRW-CHZ', 'created_at': '2021-05-16T16:22:33+09:00', 'volume': None, 'remaining_volume': None, 'reserved_fee': '49.85', 'remaining_fee': '49.85', 'paid_fee': '0.0', 'locked': '99749.85', 'executed_volume': '0.0', 'trades_count': 0}
# [{'currency': 'KRW', 'balance': '897118.75685813', 'locked': '0.0', 'avg_buy_price': '0', 'avg_buy_price_modified': True, 'unit_currency': 'KRW'}, {'currency': 'CHZ', 'balance': '174.60595446', 'locked': '0.0', 'avg_buy_price': '571', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}]
# {'uuid': '60eb3e72-b4b8-4f87-94f7-c1d6ead8e807', 'side': 'ask', 'ord_type': 'limit', 'price': '582.0', 'state': 'wait', 'market': 'KRW-CHZ', 'created_at': '2021-05-16T16:22:36+09:00', 'volume': '174.60595446', 'remaining_volume': '174.60595446', 'reserved_fee': '0.0', 'remaining_fee': '0.0', 'paid_fee': '0.0', 'locked': '174.60595446', 'executed_volume': '0.0', 'trades_count': 0}

# %%
#비현코 패키지

class py_bhc_upbit(abc):
    print(abc)
# Out:
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-edc42c918dff> in <module>
#       1 #비현코 패키지
#       2
# ----> 3 class py_bhc_upbit(abc):
#       4     print(abc)
#
# TypeError: int() takes at most 2 arguments (3 given)
