# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

# WebDriver 설정
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 페이지 열기 (여기에 페이지 URL을 넣으세요)
url = "https://www.billboard.com/charts/hot-100/"  # 예시 URL, 실제 URL로 수정 필요
driver.get(url)

# 페이지가 로드될 때까지 잠시 대기
sleep(5)

# Song Title과 Artist Name을 담을 리스트
songs_and_artists = []

# Song Title과 Artist Name을 포함하는 HTML 요소를 찾기
# 해당 클래스명을 기반으로 Song Title과 Artist Name을 찾아서 추출
items = driver.find_elements(By.CSS_SELECTOR, '.o-chart-results-list__item')

for item in items:
    try:
        # Song Title과 Artist Name 추출
        song_title = item.find_element(By.CSS_SELECTOR, '.c-title').text.strip()
        artist_name = item.find_element(By.CSS_SELECTOR, '.c-label').text.strip()
        
        # Song Title과 Artist Name을 리스트에 추가
        songs_and_artists.append((song_title, artist_name))
    except:
        # 예외 처리: Song Title이나 Artist Name이 없는 경우
        continue

# 추출된 결과 출력
for song, artist in songs_and_artists:
    print(f"Song: {song}, Artist: {artist}")

input()
# Out:
# Song: Luther, Artist: Kendrick Lamar & SZA
# Song: Die With A Smile, Artist: Lady Gaga & Bruno Mars
# Song: Not Like Us, Artist: Kendrick Lamar
# Song: A Bar Song (Tipsy), Artist: Shaboozey
# Song: TV Off, Artist: Kendrick Lamar Featuring Lefty Gunplay
# Song: APT., Artist: ROSE & Bruno Mars
# Song: Pink Pony Club, Artist: Chappell Roan
# Song: Nokia, Artist: Drake
# Song: Birds Of A Feather, Artist: Billie Eilish
# Song: Lose Control, Artist: Teddy Swims
# Song: That's So True, Artist: Gracie Abrams
# Song: Beautiful Things, Artist: Benson Boone
# Song: Anxiety, Artist: Doechii
# Song: I Had Some Help, Artist: Post Malone Featuring Morgan Wallen
# Song: Love Somebody, Artist: Morgan Wallen
# Song: Squabble Up, Artist: Kendrick Lamar
# Song: I'm The Problem, Artist: Morgan Wallen
# Song: Espresso, Artist: Sabrina Carpenter
# Song: Abracadabra, Artist: Lady Gaga
# Song: 30 For 30, Artist: SZA With Kendrick Lamar
# Song: Timeless, Artist: The Weeknd & Playboi Carti
# Song: Sports Car, Artist: Tate McRae
# Song: Denial Is A River, Artist: Doechii
# Song: Messy, Artist: Lola Young
# Song: Taste, Artist: Sabrina Carpenter
# Song: Too Sweet, Artist: Hozier
# Song: Good Luck, Babe!, Artist: Chappell Roan
# Song: Stargazing, Artist: Myles Smith
# Song: Who, Artist: Jimin
# Song: Bed Chem, Artist: Sabrina Carpenter
# Song: Revolving Door, Artist: Tate McRae
# Song: Liar, Artist: Jelly Roll
# Song: All The Stars, Artist: Kendrick Lamar & SZA
# Song: I Never Lie, Artist: Zach Top
# Song: DTMF, Artist: Bad Bunny
# Song: High Road, Artist: Koe Wetzel & Jessie Murph
# Song: I'm Gonna Love You, Artist: Cody Johnson & Carrie Underwood
# Song: Sailor Song, Artist: Gigi Perez
# Song: BMF, Artist: SZA
# Song: Die Trying, Artist: PARTYNEXTDOOR, Drake & Yebba
# Song: No One Noticed, Artist: The Marias
# Song: Indigo, Artist: Sam Barber Featuring Avery Anna
# Song: Ordinary, Artist: Alex Warren
# Song: Baile Inolvidable, Artist: Bad Bunny
