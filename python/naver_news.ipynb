# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
import pandas as pd
from tqdm import tqdm  # tqdm 임포트
import csv

# WebDriver 설정
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 네이버 뉴스 사이트 열기
url = "https://news.naver.com/"  # 예시 URL, 실제 URL로 수정 필요
driver.get(url)

# 잠시 대기 (페이지 로딩)
sleep(2)

try:
    # class="cnf_news_title" 요소 모두 찾기
    titles = driver.find_elements(By.CLASS_NAME, "cnf_news_title")
    
    # 반복하며 텍스트 출력
    for idx, title in enumerate(titles, start=1):
        print(f"{idx}. {title.text}")
finally:
    input()
# Out:
# 1. "스파게티 괴물연맹도 탄핵합니다"…시위 이색 깃발 눈길
# 2. "대만보다 못하다"…계엄 혼란 韓증시
# 3. [ZD브리핑] 尹대통령 탄핵안 재발의...예산안 국회 논의 중단 '정국 혼돈'
# 4. “계엄 사건 우리가 수사” 공수처, 검·경에 이첩 요청
# 5. Yoon survives impeachment vote after his party walks out
# 6. 이상민 행안부 장관 사의 표명… 윤 대통령 수용
# 7. 비상계엄 사태에 의대생들 "尹 퇴진 전 복귀 없어"
# 8. 尹 탄핵안 재발의 벼르는 巨野, 與 이탈표(8명)를 잡아라 '특명'
# 9. [속보] 이재명 "여당, 윤 대통령 직무배제 사실상 방해…명백한 내란 공범"
# 10. 우원식 "대통령 권한, 총리·여당이 공동 행사하면 명백한 위헌"
# 11. [긴급 기고] 질서있는 퇴진은 탄핵뿐이다
# 12. 단통법 폐지, 연내 어렵나…"오히려 기회" [IT클로즈업]
# 13. [속보] 이재명 "여당, 윤석열 직무배제 사실상 방해‥명백한 내란 공범"
# 14. 대법원, 계획대로 12일 조국 상고심 선고
# 15. 이상민 장관 사의 표명 "국민께 송구"
# 16. 윤석열, 내란 혐의 피의자 입건
# 17. [속보] 개혁신당 허은아 "헌법에 권력이 한동훈으로부터 나온다고 적혀 있나?"
# 18. 한덕수 총리 임시국무회의 취소...尹 대신 한동훈과 정례회동
# 19. 윤대통령, 이상민 장관 사의 재가에…민주 "인사권 행사 밝혀져"
# 20. 尹, 내년 6월 하야 땐 8월 대선...탄핵? 검경 수사·시위 규모에 달렸다
# 21. 홍준표 "국민이 니한테 권한 맡긴 적 없다, 내려와라" 한동훈 직격
# 22. [속보]이재명 "14일 국민의 이름으로 반드시 윤석열 탄핵"
# 23. 우원식 “국회와 상의해 일하겠다”는 한덕수에 “인정 못 해”
# 24. [속보] 이재명 “與, 尹 직무배제 사실상 방해…명백한 내란 공범”
# 25. “소수 여당 대표가 과도 정부 운영? 초법적”“오직 탄핵만 피하겠다는 국민의힘 꼼수”
# 26. 홍준표, 한동훈 향해 "너도 내려오너라…사퇴하는 게 책임정치"
# 27. [속보]이재명 "韓韓 대통령 권한 행사는 헌정질서 파괴"
# 28. ‘2선 후퇴’ 尹대통령이 재가… ‘재탄핵 위기’ 이상민 사의
# 29. 안성에 명품 산길 66km 열렸다 [안성 금북정맥 국가생태문화탐방로 특집]
# 30. [속보]개혁신당 허은아 “헌법에 권력이 한동훈으로부터 나오나”
# 31. [속보]이재명 "12월 14일, 국민의 이름으로 반드시 尹 탄핵할 것"
# 32. 방산 빅4, '계엄' 후폭풍…"정치 불안이 수출 차질"
# 33. 브루스 윌리스부터 로빈 윌리엄스까지… 치매로 고생한 할리우드 스타 5人, 누구?
# 34. [탄핵정국] 尹 지지율 계엄 이후 13% 급락…한자릿수 가나
# 35. 검찰 특수본 "尹대통령 피의자 입건…내란·직권남용 혐의 모두 수사"
# 36. '12.3 계엄사태' 검·경 수사 엇박자…합동수사 난항
# 37. 출석 6시간 만에 김용현 체포…尹수사 시계, 탄핵보다 빨리 도나
